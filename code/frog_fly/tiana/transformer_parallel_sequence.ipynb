# %% [markdown]
# ## 3.0 PPO + Transformer-Based Policy Network
#
# To incorporate temporal context into PPO, we replace the MLP policy with a Transformer policy.
# Instead of conditioning only on the current state, the agent receives a short history of experience and attends to relevant past transitions.
#
# ---
#
# ### Sequential Input Representation
#
# At timestep \(t\), we construct a window of recent experience:
#
# $$
# \mathcal{E}_t = \big[(s_{t-T+1}, a_{t-T+1}), \dots, (s_{t-1},a_{t-1}), (s_t,a_t)\big]
# $$
#
# Each element is embedded using a small MLP:
#
# $$
# x_i = \mathrm{MLP}_{\text{embed}}([s_i, a_i])
# $$
#
# ---
#
# ### Temporal Positional Encoding
#
# Because self-attention is order-invariant, we inject temporal indices using sinusoidal encodings:
#
# $$
# PE(i) = [\sin(\omega_k i), \cos(\omega_k i)]_{k=1}^{F}
# $$
#
# The input token for the Transformer becomes:
#
# $$
# z_i = x_i \;\Vert\; PE(i)
# $$
#
# ---
#
# ### Transformer Encoder Block
#
# A Transformer layer processes the sequence by attending over past and recent experience:
#
# $$
# H^{(l+1)} = \mathrm{LN}\Big(H^{(l)} +
# \mathrm{MHA}(H^{(l)}, H^{(l)}, H^{(l)})\Big)
# $$
#
# $$
# H^{(l+1)} = \mathrm{LN}\Big(H^{(l)} + \mathrm{FFN}(H^{(l)})\Big)
# $$
#
# The final hidden state \(H_T\) serves as a context summary for decision-making.
#
# ---
#
# ### Policy & Value Outputs
#
# $$
# \pi_\theta(a_t|\mathcal{E}_t) =
# \mathrm{Softmax}(\mathrm{MLP}_{\text{policy}}(H_T))
# $$
#
# $$
# V_\phi(\mathcal{E}_t) =
# \mathrm{MLP}_{\text{value}}(H_T)
# $$
#
# This allows PPO to act based on *recent experience*, not just a single observation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 (needed for 3D)

import gymnasium as gym
from gymnasium import spaces

import ray
from ray.rllib.algorithms.ppo import PPOConfig

# %%
def positional_encoding_3d(pos, num_freqs=4, max_freq=10.0):
    """
    pos: np.array shape (3,) with (x, y, z) in [-space_size, space_size].
    Returns: encoding vector of shape (3 * 2 * num_freqs,)
    """
    pos = np.asarray(pos, dtype=np.float32)
    assert pos.shape == (3,)

    freqs = np.linspace(1.0, max_freq, num_freqs)
    enc = []
    for coord in pos:            # x, y, z
        for f in freqs:
            enc.append(np.sin(f * coord))
            enc.append(np.cos(f * coord))
    return np.array(enc, dtype=np.float32)


class FrogFly3DEnv(gym.Env):
    """
    3D continuous environment:
    - Frog (agent) moves to catch a moving fly.
    - Observations: positions + relative vector + positional encodings.
    """
    metadata = {"render_modes": ["human"], "render_fps": 30}

    def __init__(self, config=None):
        super().__init__()

        if config is None:
            config = {}

        self.space_size = float(config.get("space_size", 1.0))
        self.step_size = float(config.get("step_size", 0.1))
        self.fly_speed = float(config.get("fly_speed", 0.05))
        self.catch_radius = float(config.get("catch_radius", 0.15))
        self.max_steps = int(config.get("max_steps", 200))
        self.num_freqs = int(config.get("num_freqs", 4))
        self.use_positional_encodings = bool(
            config.get("use_positional_encodings", True)
        )

        # NEW: how "wobbly" the fly’s direction is
        self.fly_noise_scale = float(config.get("fly_noise_scale", 0.1))

        # Action = 3D movement in [-1, 1]^3
        self.action_space = spaces.Box(
            low=-1.0, high=1.0, shape=(3,), dtype=np.float32
        )

        # Observation components
        # frog_pos (3) + fly_pos (3) + rel (3) = 9
        base_dim = 9
        if self.use_positional_encodings:
            pe_dim = 3 * 2 * self.num_freqs  # per position
            obs_dim = base_dim + 2 * pe_dim
        else:
            obs_dim = base_dim

        self.observation_space = spaces.Box(
            low=-5.0, high=5.0, shape=(obs_dim,), dtype=np.float32
        )

        self.frog_pos = None
        self.fly_pos = None
        self.fly_vel = None      # NEW: persistent fly velocity
        self.steps = 0
        self._value_out = None

    # ---------- Helpers ----------

    def _sample_position(self):
        return np.random.uniform(
            low=-self.space_size,
            high=self.space_size,
            size=(3,),
        ).astype(np.float32)

    def _clip_position(self, pos):
        return np.clip(pos, -self.space_size, self.space_size).astype(np.float32)

    def _get_obs(self):
        rel = self.fly_pos - self.frog_pos
        parts = [self.frog_pos, self.fly_pos, rel]

        if self.use_positional_encodings:
            frog_pe = positional_encoding_3d(self.frog_pos, self.num_freqs)
            fly_pe = positional_encoding_3d(self.fly_pos, self.num_freqs)
            parts.extend([frog_pe, fly_pe])

        return np.concatenate(parts, axis=0).astype(np.float32)

    def _get_distance(self):
        return float(np.linalg.norm(self.fly_pos - self.frog_pos))

    # ---------- Gymnasium API ----------

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.steps = 0
        self.frog_pos = self._sample_position()
        self.fly_pos = self._sample_position()

        # NEW: initialize persistent fly velocity
        dir0 = np.random.normal(size=(3,)).astype(np.float32)
        dir0 /= np.linalg.norm(dir0) + 1e-8
        self.fly_vel = self.fly_speed * dir0

        obs = self._get_obs()
        info = {}
        return obs, info

    def step(self, action):
        self.steps += 1

        action = np.asarray(action, dtype=np.float32)
        action = np.clip(action, -1.0, 1.0)

        # Frog moves
        self.frog_pos = self.frog_pos + self.step_size * action
        self.frog_pos = self._clip_position(self.frog_pos)

        # NEW: Fly moves with persistent velocity + small noise
        noise = self.fly_noise_scale * np.random.normal(size=(3,)).astype(np.float32)
        self.fly_vel = self.fly_vel + noise

        # keep constant speed = fly_speed
        self.fly_vel /= np.linalg.norm(self.fly_vel) + 1e-8
        self.fly_vel = self.fly_speed * self.fly_vel

        self.fly_pos = self.fly_pos + self.fly_vel
        self.fly_pos = self._clip_position(self.fly_pos)

        # Distance and termination
        dist = self._get_distance()
        caught = dist < self.catch_radius

        # Reward shaping: closer is better + bonus for catch
        reward = -dist
        if caught:
            reward += 10.0

        terminated = caught
        truncated = self.steps >= self.max_steps

        obs = self._get_obs()
        info = {"distance": dist, "caught": caught}

        return obs, reward, terminated, truncated, info

    def render(self):
        print(
            f"Step {self.steps} | "
            f"Frog: {self.frog_pos} | Fly: {self.fly_pos} | "
            f"Dist: {self._get_distance():.3f}"
        )

    def close(self):
        pass

# %%
from ray.tune.registry import register_env

# K-step observation history wrapper (if you don't already have this)
class ObsHistoryWrapper(gym.Wrapper):
    def __init__(self, env, K=8):
        super().__init__(env)
        self.K = K
        obs_shape = env.observation_space.shape  # (D,)
        self.history = np.zeros((K,) + obs_shape, dtype=np.float32)

        low  = np.repeat(env.observation_space.low[None, :],  K, axis=0)
        high = np.repeat(env.observation_space.high[None, :], K, axis=0)
        self.observation_space = gym.spaces.Box(low=low, high=high, dtype=np.float32)

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self.history[:] = obs
        return self.history.copy(), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        self.history = np.roll(self.history, shift=-1, axis=0)
        self.history[-1] = obs
        return self.history.copy(), reward, terminated, truncated, info

# Factory for RLlib
def make_frog_hist_env(env_config):
    base_env = FrogFly3DEnv(env_config)
    return ObsHistoryWrapper(base_env, K=8)

# Register under a name RLlib understands
register_env("frog_hist_env", make_frog_hist_env)

# %%
import numpy as np
import torch
import torch.nn as nn
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models import ModelCatalog

ray.shutdown()
ray.init(ignore_reinit_error=True)

class FrogTransformerModel(TorchModelV2, nn.Module):
    def __init__(
        self,
        obs_space,
        action_space,
        num_outputs,
        model_config,
        name,
        **kwargs,
    ):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)

        # Expect obs shape = (K, obs_dim_single)
        assert len(obs_space.shape) == 2, f"Expected (K, D), got {obs_space.shape}"
        self.seq_len    = obs_space.shape[0]  # K (time)
        self.feature_dim = obs_space.shape[1] # D (per-timestep features)

        cmc = model_config.get("custom_model_config", {}) or {}

        def get_hp(key, default):
            return kwargs.get(key, cmc.get(key, default))

        d_model    = get_hp("d_model", 64)
        nhead      = get_hp("nhead", 4)
        num_layers = get_hp("num_layers", 1)
        dim_ff     = get_hp("dim_feedforward", 128)
        dropout    = get_hp("dropout", 0.1)

        # Embedding per timestep (map R^{D} -> R^{d_model})
        self.embed = nn.Linear(self.feature_dim, d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_ff,
            dropout=dropout,
            batch_first=True,
            activation="relu",
        )
        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=num_layers,
        )

        self.policy_head = nn.Sequential(
            nn.Linear(d_model, d_model),
            nn.ReLU(),
            nn.Linear(d_model, num_outputs),
        )
        self.value_head = nn.Sequential(
            nn.Linear(d_model, d_model),
            nn.ReLU(),
            nn.Linear(d_model, 1),
        )

        self._features = None

    def forward(self, input_dict, state, seq_lens):
        # Get obs as float tensor, whatever its shape is
        x = input_dict["obs"].float()       # shape: (B, ...) with possibly >2 dims
        B = x.shape[0]

        # Flatten all non-batch dims into a single feature dimension
        x = x.view(B, -1)                   # shape: (B, F_flat)
        F = x.shape[1]

        # --- Infer how to interpret the obs as (B, K, D) sequence ---
        # Case 1: env gives a single feature vector of length feature_dim → treat as K=1
        if F == self.feature_dim:
            K = 1
        # Case 2: env gives a flattened sequence of length seq_len * feature_dim
        elif F == self.seq_len * self.feature_dim:
            K = self.seq_len
        else:
            raise RuntimeError(
                f"Cannot reshape obs of size {F} into "
                f"(B, K, feature_dim={self.feature_dim}) with seq_len={self.seq_len}."
            )

        # Reshape to (B, K, D)
        x = x.view(B, K, self.feature_dim)

        # --- Standard Transformer forward ---
        # (B, K, D) → (B, K, d_model)
        x = self.embed(x)

        # Optional: positional encodings, if you defined self.pos_embed
        if hasattr(self, "pos_embed"):
            # assume pos_embed has shape (1, max_K, d_model)
            x = x + self.pos_embed[:, :K, :]

        # TransformerEncoder expects (K, B, d_model)
        x = x.transpose(0, 1)          # (K, B, d_model)
        x = self.transformer(x)        # (K, B, d_model)
        x = x.transpose(0, 1)          # (B, K, d_model)

        # Pooling: take last token
        token = x[:, -1, :]            # (B, d_model)

        # Policy and value heads
        logits = self.policy_head(token)     # (B, num_actions)
        value  = self.value_head(token)      # (B, 1)

        # RLlib expects value via this attribute
        self._value_out = value.squeeze(-1)  # (B,)

        # Return logits + empty RNN state list
        return logits, []

    def value_function(self):
        # RLlib calls this after forward() to get V(s).
        if self._value_out is None:
            raise ValueError("value_function() called before forward().")
        return self._value_out




ModelCatalog.register_custom_model("frog_transformer_policy", FrogTransformerModel)
# Out:
# 2025-12-02 15:06:03,482	INFO worker.py:2023 -- Started a local Ray instance.
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(

# %%
def make_frog_env(env_config):
    base_env = FrogFly3DEnv(env_config)
    return ObsHistoryWrapper(base_env, K=8)  # e.g., last 8 obs

# %%
from ray.rllib.algorithms.ppo import PPOConfig

env_config = {
    "space_size": 1.0,
    "step_size": 0.1,
    "fly_speed": 0.05,
    "catch_radius": 0.15,
    "max_steps": 200,
    "num_freqs": 4,
    "use_positional_encodings": True,
}

config = (
    PPOConfig()
    .environment(
        env="frog_hist_env",    # registered history-wrapped env
        env_config=env_config,
    )
    .framework("torch")
    .api_stack(
        enable_rl_module_and_learner=False,
        enable_env_runner_and_connector_v2=False,
    )
    .env_runners(
        num_env_runners=1,
        num_envs_per_env_runner=8,
        create_env_on_local_worker=True,
    )
    .resources(num_gpus=0)
    .training(
        model={
            "custom_model": "frog_transformer_policy",
            "custom_model_config": {
                "d_model": 64,
                "nhead": 4,
                "num_layers": 1,
                "dim_feedforward": 128,
                "dropout": 0.1
            },
        },
        gamma=0.99,
        lr=1e-4,          # a bit conservative to help with stability
        grad_clip=0.5,    # gradient clipping threshold
        grad_clip_by="global_norm",  # (this is the default but being explicit)
        train_batch_size=4000,
        num_epochs=10,
        minibatch_size=512,
        clip_param=0.2,
        entropy_coeff=0.01
    )
    .evaluation(
        evaluation_duration=20,              # 20 eval episodes instead of 10
        evaluation_duration_unit="episodes", # interpret that as episodes
        # optional, but good practice:
        evaluation_config={
            "explore": False,               # greedy eval
        },
    ) 
)

algo = config.build()
print("Algo built OK with grad clipping")
# Out:
# 2025-12-02 15:06:04,128	WARNING 3666910297.py:61 -- DeprecationWarning: `build` has been deprecated. Use `AlgorithmConfig.build_algo` instead. This will raise an error in the future!
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# [2025-12-02 15:06:04,206 E 29144 64631986] core_worker.cc:2223: Actor with class name: 'RolloutWorker' and ID: '9af246cb129be82169f4997f01000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# 2025-12-02 15:06:06,921	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Algo built OK with grad clipping

# %%
res = algo.train()
print(res.keys())
print(res)
# Out:
# 2025-12-02 15:06:08,012	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# dict_keys(['custom_metrics', 'episode_media', 'info', 'env_runners', 'num_healthy_workers', 'actor_manager_num_outstanding_async_reqs', 'num_remote_worker_restarts', 'num_agent_steps_sampled', 'num_agent_steps_trained', 'num_env_steps_sampled', 'num_env_steps_trained', 'num_env_steps_sampled_this_iter', 'num_env_steps_trained_this_iter', 'num_env_steps_sampled_throughput_per_sec', 'num_env_steps_trained_throughput_per_sec', 'timesteps_total', 'num_env_steps_sampled_lifetime', 'num_agent_steps_sampled_lifetime', 'num_steps_trained_this_iter', 'agent_timesteps_total', 'timers', 'counters', 'done', 'training_iteration', 'trial_id', 'date', 'timestamp', 'time_this_iter_s', 'time_total_s', 'pid', 'hostname', 'node_ip', 'config', 'time_since_restore', 'iterations_since_restore', 'perf'])
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float64(0.5), 'cur_kl_coeff': np.float64(0.19999999999999993), 'cur_lr': np.float64(0.00010000000000000005), 'total_loss': np.float64(10.118064853123256), 'policy_loss': np.float64(0.19378914680065853), 'vf_loss': np.float64(9.921778270176478), 'vf_explained_var': np.float64(-0.0014283520834786551), 'kl': np.float64(0.2412467807531357), 'entropy': np.float64(4.575184781210763), 'entropy_coeff': np.float64(0.01)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(512.0), 'num_grad_updates_lifetime': np.float64(35.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(34.5)}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'env_runners': {'episode_reward_max': 9.853726863861084, 'episode_reward_min': -478.9563547372818, 'episode_reward_mean': np.float64(-276.2269014219443), 'episode_len_mean': np.float64(178.22222222222223), 'episode_media': {}, 'episodes_timesteps_total': 3208, 'policy_reward_min': {'default_policy': np.float64(-478.9563547372818)}, 'policy_reward_max': {'default_policy': np.float64(9.853726863861084)}, 'policy_reward_mean': {'default_policy': np.float64(-276.2269014219443)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [8.325318530201912, -390.5133421421051, -293.10728055238724, -478.9563547372818, -282.57776576280594, -360.53646767139435, -151.23911191523075, -299.41843605041504, -193.40486207604408, -330.3354293704033, -269.07380121946335, -319.05917143821716, -377.23785614967346, -293.0182312130928, -394.37234473228455, -298.2514052093029, -259.1614107489586, 9.853726863861084], 'episode_lengths': [7, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 1], 'policy_default_policy_reward': [8.325318530201912, -390.5133421421051, -293.10728055238724, -478.9563547372818, -282.57776576280594, -360.53646767139435, -151.23911191523075, -299.41843605041504, -193.40486207604408, -330.3354293704033, -269.07380121946335, -319.05917143821716, -377.23785614967346, -293.0182312130928, -394.37234473228455, -298.2514052093029, -259.1614107489586, 9.853726863861084]}, 'sampler_perf': {'mean_raw_obs_processing_ms': np.float64(0.7526236855817174), 'mean_inference_ms': np.float64(0.55442551176943), 'mean_action_processing_ms': np.float64(0.3129831569161482), 'mean_env_wait_ms': np.float64(0.48783201419426775), 'mean_env_render_ms': np.float64(0.0)}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': np.float64(0.002235836452907986), 'StateBufferConnector_ms': np.float64(0.010727511511908637), 'ViewRequirementAgentConnector_ms': np.float64(0.03664890925089518)}, 'num_episodes': 18, 'episode_return_max': 9.853726863861084, 'episode_return_min': -478.9563547372818, 'episode_return_mean': np.float64(-276.2269014219443), 'episodes_this_iter': 18}, 'num_healthy_workers': 1, 'actor_manager_num_outstanding_async_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 678.0661851490099, 'num_env_steps_trained_throughput_per_sec': 678.0661851490099, 'timesteps_total': 4000, 'num_env_steps_sampled_lifetime': 4000, 'num_agent_steps_sampled_lifetime': 4000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 4000, 'timers': {'training_iteration_time_ms': 5899.136, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 5899.106, 'sample_time_ms': 1084.988, 'load_time_ms': 0.208, 'load_throughput': 19239926.606, 'learn_time_ms': 4811.047, 'learn_throughput': 831.42, 'synch_weights_time_ms': 2.146}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained':  ...

# %%
def get_train_metrics(result):
    """Extract mean reward and len from an RLlib result dict (env_runners layout)."""
    er = result.get("env_runners", {})
    reward_mean = float(er.get("episode_return_mean", float("nan")))
    len_mean    = float(er.get("episode_len_mean", float("nan")))
    return reward_mean, len_mean

# %%
import numpy as np

eval_env = ObsHistoryWrapper(FrogFly3DEnv(env_config), K=8)  # reuse your env_config


def evaluate_policy(algo, env, num_episodes=5, render=False):
    """
    Evaluate a single-agent policy using the legacy RLlib API.

    Uses algo.compute_single_action(obs, ...) which is the right call
    for this RLlib version (compute_actions is multi-agent only here).
    """
    returns = []
    lengths = []

    for _ in range(num_episodes):
        obs, info = env.reset()
        done = False
        ep_ret = 0.0
        steps = 0

        while not done:
            # Single-agent action: returns (action, state_out, info)
            action, _, _ = algo.compute_single_action(obs, explore=False)

            obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            ep_ret += reward
            steps += 1

            if render:
                env.render()

        returns.append(ep_ret)
        lengths.append(steps)

    return {
        "mean_return": float(np.mean(returns)),
        "std_return": float(np.std(returns)),
        "mean_length": float(np.mean(lengths)),
    }

# %%
import os

num_iterations = 200        # how long you want to train
eval_interval  = 10         # how often to run eval
eval_episodes  = 20

train_history = []          # for plotting later
best_eval_return = -float("inf")
checkpoint_dir = "frog_transformer_checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

for i in range(1, num_iterations + 1):
    # ---- 1. One PPO training iteration ----
    result = algo.train()
    train_reward, train_len = get_train_metrics(result)

    # ---- 2. Periodic evaluation ----
    if i % eval_interval == 0:
        eval_stats = evaluate_policy(
            algo,
            eval_env,
            num_episodes=eval_episodes,
            render=False,
        )
        eval_return = eval_stats["mean_return"]
        eval_len    = eval_stats["mean_length"]

        print(
            f"[Iter {i:4d}] "
            f"train_reward={train_reward:8.2f}, "
            f"train_len={train_len:6.1f} | "
            f"eval_return={eval_return:8.2f}, "
            f"eval_len={eval_len:6.1f}"
        )

        # Save history for plotting
        train_history.append(
            {
                "iter": i,
                "train_reward": train_reward,
                "train_len": train_len,
                "eval_return": eval_return,
                "eval_len": eval_len,
            }
        )

        # save best checkpoint
        if eval_return > best_eval_return:
            best_eval_return = eval_return
            checkpoint_path = algo.save(checkpoint_dir)
            print(f"  New best eval_return={best_eval_return:.2f}, saved to {checkpoint_path}")
    else:
        # Lighter log on non-eval iterations
        print(
            f"[Iter {i:4d}] "
            f"train_reward={train_reward:8.2f}, "
            f"train_len={train_len:6.1f}"
        )
# Out:
# [Iter    1] train_reward= -299.75, train_len= 189.7
# [Iter    2] train_reward= -305.59, train_len= 192.7
# [Iter    3] train_reward= -285.23, train_len= 189.9
# (pid=gcs_server) [2025-12-02 15:06:32,816 E 29200 64632281] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-02 15:06:33,453 E 29212 64632429] (raylet) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=29215) [2025-12-02 15:06:33,999 E 29215 64632740] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-02 15:06:34,132 E 29144 64632480] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [Iter    4] train_reward= -289.32, train_len= 192.3
# [Iter    5] train_reward= -292.31, train_len= 192.8
# [Iter    6] train_reward= -286.81, train_len= 191.6
# [Iter    7] train_reward= -286.61, train_len= 191.2
# [Iter    8] train_reward= -303.98, train_len= 193.3
# [Iter    9] train_reward= -313.09, train_len= 194.7
# 2025-12-02 15:07:11,173	WARNING 2225480022.py:24 -- DeprecationWarning: `compute_single_action` has been deprecated. `Algorithm.compute_single_action` should no longer be used. Get the RLModule instance through `Algorithm.get_module([module ID])`, then compute actions through `RLModule.forward_inference({'obs': [obs batch]})`. This will raise an error in the future!
# [Iter   10] train_reward= -310.61, train_len= 196.2 | eval_return= -261.68, eval_len= 192.4
#   New best eval_return=-261.68, saved to TrainingResult(checkpoint=Checkpoint(filesystem=local, path=frog_transformer_checkpoints), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float64(0.5), 'cur_kl_coeff': np.float64(0.3000000000000001), 'cur_lr': np.float64(0.00010000000000000005), 'total_loss': np.float64(9.782550457545689), 'policy_loss': np.float64(0.03497531030859266), 'vf_loss': np.float64(9.787804290226527), 'vf_explained_var': np.float64(-0.008164823055267334), 'kl': np.float64(0.010091874934732913), 'entropy': np.float64(4.3256553990500315), 'entropy_coeff': np.float64(0.01)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(512.0), 'num_grad_updates_lifetime': np.float64(735.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(34.5)}}, 'num_env_steps_sampled': 44000, 'num_env_steps_trained': 44000, 'num_agent_steps_sampled': 44000, 'num_agent_steps_trained': 44000}, 'env_runners': {'episode_reward_max': 8.79108975827694, 'episode_reward_min': -502.76184153556824, 'episode_reward_mean': np.float64(-310.60953565493224), 'episode_len_mean': np.float64(196.22), 'episode_media': {}, 'episodes_timesteps_total': 19622, 'policy_reward_min': {'default_policy': np.float64(-502.76184153556824)}, 'policy_reward_max': {'default_policy': np.float64(8.79108975827694)}, 'policy_reward_mean': {'default_policy': np.float64(-310.60953565493224)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-430.31759011745453, -344.4745841026306, -363.04043847322464, -288.1892243027687, -224.07497936487198, -373.6113042831421, -316.7370761036873, -243.87038111686707, -334.4295800924301, -289.96233201026917, -205.97433385252953, -454.08178555965424, -285.0888189673424, -154.73887164890766, -391.88831067085266, -340.94058656692505, -357.87573540210724, -282.2511051893234, -27.090837851166725, -328.54787373542786, -210.33204022049904, -379.0694110393524, -385.5666024684906, -402.8416714668274, -260.7324340939522, -276.50758922100067, -443.7310415506363, -453.09538877010345, -371.92958176136017, -215.67475759983063, -244.3117888867855, -287.24042296409607, -380.072825551033, -406.0789061784744, -250.6949965953827, -364.9900411963463, -378.3228100538254, -194.73339635133743, -211.02116799354553, -201.6935976743698, -241.18629425764084, -242.889355301857, 8.79108975827694, -363.74413764476776, -408.7344481945038, -434.0221800804138, -452.7494181394577, -322.65479212999344, -406.00643813610077, -274.7694646716118, -201.22510147094727, -218.77544552087784, -191.7651999592781, -251.42098432779312, -289.6015956401825, -402.5451417565346, -374.63837802410126, -237.91112101078033, -502.76184153556824, -397.26562774181366, -425.8309237957001, -353.95506978034973, -219.61882677674294, -360.1276181936264, -245.8183026611805, -412.29291784763336, -356.6397711932659, -194.99720031023026, -284.4027887880802, -373.0496826171875, -256.8302793800831, -445.42125165462494, -225.74676966667175, -227.50560829043388, -339.35850262641907, -267.82447224855423, -400.48368406295776, -358.720667719841, -400.1175458431244, -419.2041765451431, -263.2525141239166, -276.8279626965523, -337.508092880249, -188.53519487380981, -272.3067427277565, -319.08145821094513, -277.72735860943794, -399.95553267002106, -410.47118175029755, -243.17508083581924, -187.95950600504875, -197.81503626704216, -326.9603242278099, -374.72042298316956, -201.70483914017677, -400.35842537879944, -364.2898176908493, -334.68337619304657, -324.67189490795135, -229.30064648389816], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 49, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 168, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 5, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 2 ...
# [Iter   11] train_reward= -311.89, train_len= 196.9
# [Iter   12] train_reward= -303.96, train_len= 193.6
# [Iter   13] train_reward= -304.86, train_len= 195.6
# [Iter   14] train_reward= -296.04, train_len= 193.3
# [Iter   15] train_reward= -296.69, train_len= 190.2
# [Iter   16] train_reward= -296.22, train_len= 191.4
# [Iter   17] train_reward= -292.74, train_len= 191.4
# [Iter   18] train_reward= -292.27, train_len= 192.4
# [Iter   19] train_reward= -290.24, train_len= 191.7
# [Iter   20] train_reward= -287.43, train_len= 194.0 | eval_return= -255.82, eval_len= 182.2
#   New best eval_return=-255.82, saved to TrainingResult(checkpoint=Checkpoint(filesystem=local, path=frog_transformer_checkpoints), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float64(0.5), 'cur_kl_coeff': np.float64(0.3000000000000001), 'cur_lr': np.float64(0.00010000000000000005), 'total_loss': np.float64(9.37959077017648), 'policy_loss': np.float64(0.027027309047324317), 'vf_loss': np.float64(9.391186087472098), 'vf_explained_var': np.float64(-0.03527571899550302), 'kl': np.float64(0.010151458691273417), 'entropy': np.float64(4.166807413101196), 'entropy_coeff': np.float64(0.01)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(512.0), 'num_grad_updates_lifetime': np.float64(1435.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(34.5)}}, 'num_env_steps_sampled': 84000, 'num_env_steps_trained': 84000, 'num_agent_steps_sampled': 84000, 'num_agent_steps_trained': 84000}, 'env_runners': {'episode_reward_max': 9.517749667167664, 'episode_reward_min': -469.6643189191818, 'episode_reward_mean': np.float64(-287.42895810581746), 'episode_len_mean': np.float64(194.03), 'episode_media': {}, 'episodes_timesteps_total': 19403, 'policy_reward_min': {'default_policy': np.float64(-469.6643189191818)}, 'policy_reward_max': {'default_policy': np.float64(9.517749667167664)}, 'policy_reward_mean': {'default_policy': np.float64(-287.42895810581746)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-352.58100843429565, -325.699454665184, -305.9039491415024, -259.16158187389374, -267.1544310450554, -327.4525908231735, -214.80941885709763, -222.1708542406559, -410.29812812805176, -224.7681723833084, -285.28668624162674, -279.794681340456, -173.7884660065174, -469.6643189191818, -263.20824083685875, -222.17836505174637, -27.90282643586397, -367.25464272499084, -400.88848865032196, -278.2658445239067, -374.3372865319252, -130.61148522794247, -227.90058785676956, -253.2888829112053, -200.9579485654831, 9.517749667167664, -239.62080225348473, -116.20912253856659, -298.3219378590584, -240.7336540222168, -359.6686450242996, -273.4175640940666, -176.56514611840248, -408.85360968112946, -300.94412863254547, -368.96807873249054, -409.03674376010895, -400.71339279413223, -299.7525677680969, -392.4037413597107, -384.78467631340027, -386.5218892097473, -311.67915511131287, -371.0181084871292, -292.6739753484726, -299.3859104514122, -149.6119213849306, -325.8611568212509, -330.73465687036514, -218.00024491548538, -297.70937126874924, -194.924760222435, -402.51884734630585, -148.37976403534412, -334.8920683860779, -263.22920447587967, -369.8005132675171, -393.4618754386902, -369.81243431568146, -312.27108228206635, -287.4797552227974, -321.32268023490906, -283.581127345562, -341.71505177021027, -306.890157520771, -398.55672121047974, -215.82754835486412, -381.2409685254097, -324.5133714079857, -394.9144239425659, -354.3487706184387, -251.5224948823452, -347.8051463365555, -228.73578584194183, -346.35201728343964, -168.54836897552013, -245.29287922382355, -372.14630830287933, -75.55146887898445, -383.7953087091446, -153.91809633374214, -399.44514429569244, -337.1479243040085, -330.5303912162781, -194.48298728466034, -308.1513895392418, -302.2452834844589, -281.52367067337036, -133.60919123888016, -416.36267364025116, -363.6447603702545, -264.07927829027176, -236.4468473792076, -244.5483351945877, -312.5486508011818, -241.98436006903648, -272.1811389327049, -120.70189800858498, -338.3952542543411, -162.51683834195137], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 65, 200, 200, 200, 200, 200, 200, 200, 200, 2, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 150, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200,  ...
# [Iter   21] train_reward= -289.19, train_len= 194.2
# [Iter   22] train_reward= -294.80, train_len= 196.2
# [Iter   23] train_reward= -296.78, train_len= 196.7
# [Iter   24] train_reward= -297.36, train_len= 196.2
# [Iter   25] train_reward= -292.03, train_len= 193.3
# [Iter   26] train_reward= -297.26, train_len= 193.4
# [Iter   27] train_reward= -293.39, train_len= 192.7
# [Iter   28] train_reward= -289.10, train_len= 190.9
# [Iter   29] train_reward= -292.01, train_len= 194.0
# [Iter   30] train_reward= -289.16, train_len= 194.4 | eval_return= -310.07, eval_len= 200.0
# [Iter   31] train_reward= -275.89, train_len= 190.8
# [Iter   32] train_reward= -276.57, train_len= 191.4
# [Iter   33] train_reward= -279.44, train_len= 190.1
# [Iter   34] train_reward= -277.20, train_len= 190.1
# [Iter   35] train_reward= -289.85, train_len= 193.2
# [Iter   36] train_reward= -296.80, train_len= 195.1
# [Iter   37] train_reward= -297.39, train_len= 195.2
# [Iter   38] train_reward= -279.47, train_len= 193.8
# [Iter   39] train_reward= -272.41, train_len= 192.1
# [Iter   40] train_reward= -271.33, train_len= 193.8 | eval_return= -329.42, eval_len= 200.0
# [Iter   41] train_reward= -262.95, train_len= 191.8
# [Iter   42] train_reward= -256.46, train_len= 188.5
# [Iter   43] train_reward= -266.25, train_len= 188.3
# [Iter   44] train_reward= -248.72, train_len= 182.0
# [Iter   45] train_reward= -249.71, train_len= 181.9
# [Iter   46] train_reward= -250.16, train_len= 185.1
# [Iter   47] train_reward= -251.87, train_len= 185.8
# [Iter   48] train_reward= -249.36, train_len= 184.6
# [Iter   49] train_reward= -258.10, train_len= 188.9
# [Iter   50] train_reward= -263.90, train_len= 190.6 | eval_return= -331.22, eval_len= 200.0
# [Iter   51] train_reward= -260.51, train_len= 188.0
# [Iter   52] train_reward= -260.96, train_len= 189.0
# [Iter   53] train_reward= -253.43, train_len= 185.7
# [Iter   54] train_reward= -241.90, train_len= 185.4
# [Iter   55] train_reward= -237.13, train_len= 187.4
# [Iter   56] train_reward= -226.70, train_len= 183.0
# [Iter   57] train_reward= -219.32, train_len= 182.4
# [Iter   58] train_reward= -218.75, train_len= 184.6
# [Iter   59] train_reward= -221.59, train_len= 185.5
# [Iter   60] train_reward= -212.86, train_len= 182.3 | eval_return= -207.64, eval_len= 173.8
#   New best eval_return=-207.64, saved to TrainingResult(checkpoint=Checkpoint(filesystem=local, path=frog_transformer_checkpoints), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float64(0.5), 'cur_kl_coeff': np.float64(0.3000000000000001), 'cur_lr': np.float64(0.00010000000000000005), 'total_loss': np.float64(8.88242118018014), 'policy_loss': np.float64(0.060116307650293625), 'vf_loss': np.float64(8.868070888519288), 'vf_explained_var': np.float64(0.1655149357659476), 'kl': np.float64(0.008905837877786585), 'entropy': np.float64(4.843768685204642), 'entropy_coeff': np.float64(0.01)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(512.0), 'num_grad_updates_lifetime': np.float64(4235.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(34.5)}}, 'num_env_steps_sampled': 244000, 'num_env_steps_trained': 244000, 'num_agent_steps_sampled': 244000, 'num_agent_steps_trained': 244000}, 'env_runners': {'episode_reward_max': 6.650660574436188, 'episode_reward_min': -372.29482197761536, 'episode_reward_mean': np.float64(-212.86480777308344), 'episode_len_mean': np.float64(182.29), 'episode_media': {}, 'episodes_timesteps_total': 18229, 'policy_reward_min': {'default_policy': np.float64(-372.29482197761536)}, 'policy_reward_max': {'default_policy': np.float64(6.650660574436188)}, 'policy_reward_mean': {'default_policy': np.float64(-212.86480777308344)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-322.215918302536, -75.76982025057077, -243.02515745162964, -182.0421929359436, -222.7958778142929, 5.146566741168499, -243.6711248755455, -187.82150256633759, -326.02630734443665, -219.07262016832829, -319.5442036986351, -226.2873670756817, -40.678609915077686, -238.81377550959587, -212.00679804384708, -61.027699783444405, 6.650660574436188, -162.3253575488925, -34.4972660318017, -307.3498878479004, -201.6774754524231, -262.5834767818451, -221.80814015865326, -210.84486550092697, -194.64483165740967, -236.02733075618744, -337.583958953619, -325.13869512081146, -213.6599706709385, -225.54864847660065, -221.17252039909363, -178.33706539869308, -201.68204772472382, -212.27516417205334, -297.46242478489876, -161.58112335205078, -200.90616616606712, -167.02772969007492, -306.4028580188751, -177.4536898881197, -213.6642535328865, -162.79539901018143, -1.366148367524147, -176.01436746120453, -289.75245374441147, -262.1264824271202, -245.55047115683556, -11.63810983300209, -269.5724987089634, -328.8963077068329, -211.5667442381382, -372.29482197761536, -206.58935913443565, -346.11652529239655, -86.86161441355944, -351.3273104429245, -163.26265242695808, -327.2790843844414, -187.87178301811218, -231.57074677944183, -214.15196898579597, -149.7231169641018, -253.59406358003616, -334.09919905662537, -274.56715792417526, -218.80034412443638, -258.9028265476227, -199.23700362443924, -271.8806538581848, -327.3831890821457, -240.51457020640373, -257.3229959011078, -174.54950699210167, -215.10176622867584, -168.3434661924839, -224.51205521821976, -163.6186806485057, -315.1898435354233, -137.62185883522034, -365.51280945539474, -246.23456871509552, -232.03964537382126, -252.55851763486862, -267.3354297876358, -240.46595627069473, -272.5806792974472, -251.3416224718094, -64.57042793929577, -204.62130117416382, -165.5069311261177, -199.45801511406898, -196.47372442483902, -20.951441064476967, -190.70656794309616, -191.8301601409912, 0.4742523059248924, -189.44288796186447, -204.27034896612167, -318.63318479061127, -200.1969654262066], 'episode_lengths': [200, 102, 200, 200, 163, 9, 200, 200, 200, 200, 200, 200, 86, 200, 190, 117, 11, 198, 74, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 32, 200, 200, 200, 200, 44, 200, 200, 200, 200, 200, 200, 181, 200, 143, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 2 ...
# [Iter   61] train_reward= -219.50, train_len= 187.2
# [Iter   62] train_reward= -221.62, train_len= 185.2
# [Iter   63] train_reward= -217.78, train_len= 186.4
# [Iter   64] train_reward= -206.19, train_len= 182.7
# [Iter   65] train_reward= -206.13, train_len= 180.0
# [Iter   66] train_reward= -194.76, train_len= 176.7
# [Iter   67] train_reward= -192.79, train_len= 176.1
# [Iter   68] train_reward= -183.30, train_len= 172.5
# [Iter   69] train_reward= -185.58, train_len= 174.3
# [Iter   70] train_reward= -192.38, train_len= 181.1 | eval_return= -220.72, eval_len= 192.1
# [Iter   71] train_reward= -199.33, train_len= 184.5
# [Iter   72] train_reward= -192.46, train_len= 180.3
# [Iter   73] train_reward= -194.49, train_len= 184.0
# [Iter   74] train_reward= -193.43, train_len= 183.4
# [Iter   75] train_reward= -199.51, train_len= 179.7
# [Iter   76] train_reward= -198.39, train_len= 182.4
# [Iter   77] train_reward= -207.59, train_len= 187.0
# [Iter   78] train_reward= -216.04, train_len= 187.9
# [Iter   79] train_reward= -218.35, train_len= 187.8
# [Iter   80] train_reward= -213.55, train_len= 188.0 | eval_return= -263.47, eval_len= 195.9
# [Iter   81] train_reward= -206.66, train_len= 185.2
# [Iter   82] train_reward= -213.23, train_len= 187.5
# [Iter   83] train_reward= -212.86, train_len= 189.2
# [Iter   84] train_reward= -205.91, train_len= 184.9
# [Iter   85] train_reward= -207.23, train_len= 183.9
# [Iter   86] train_reward= -207.55, train_len= 186.1
# [Iter   87] train_reward= -192.57, train_len= 178.7
# [Iter   88] train_reward= -184.08, train_len= 172.9
# [Iter   89] train_reward= -177.24, train_len= 170.8
# [Iter   90] train_reward= -178.39, train_len= 168.8 | eval_return= -216.59, eval_len= 189.7
# [Iter   91] train_reward= -175.33, train_len= 168.0
# [Iter   92] train_reward= -176.55, train_len= 167.2
# [Iter   93] train_reward= -174.92, train_len= 167.4
# [Iter   94] train_reward= -175.94, train_len= 171.3
# [Iter   95] train_reward= -176.37, train_len= 174.4
# [Iter   96] train_reward= -181.12, train_len= 178.3
# [Iter   97] train_reward= -184.03, train_len= 178.8
# [Iter   98] train_reward= -184.53, train_len= 177.8
# [Iter   99] train_reward= -190.84, train_len= 180.9
# [Iter  100] train_reward= -191.73, train_len= 179.7 | eval_return= -243.07, eval_len= 192.0
# [Iter  101] train_reward= -182.31, train_len= 177.4
# [Iter  102] train_reward= -189.21, train_len= 181.3
# [Iter  103] train_reward= -193.44, train_len= 182.7
# [Iter  104] train_reward= -184.43, train_len= 181.7
# [Iter  105] train_reward= -184.44, train_len= 180.8
# [Iter  106] train_reward= -193.03, train_len= 184.3
# [Iter  107] train_reward= -185.73, train_len= 179.4
# [Iter  108] train_reward= -186.64, train_len= 178.6
# [Iter  109] train_reward= -186.66, train_len= 177.2
# [Iter  110] train_reward= -185.39, train_len= 177.7 | eval_return= -269.43, eval_len= 197.1
# [Iter  111] train_reward= -185.30, train_len= 176.9
# [Iter  112] train_reward= -179.51, train_len= 172.2
# [Iter  113] train_reward= -177.38, train_len= 171.2
# [Iter  114] train_reward= -175.49, train_len= 169.0
# [Iter  115] train_reward= -174.62, train_len= 168.2
# [Iter  116] train_reward= -178.86, train_len= 174.7
# [Iter  117] train_reward= -189.92, train_len= 181.7
# [Iter  118] train_reward= -187.36, train_len= 180.4
# [Iter  119] train_reward= -183.62, train_len= 180.2
# [Iter  120] train_reward= -177.66, train_len= 174.6 | eval_return= -260.94, eval_len= 183.5
# [Iter  121] train_reward= -174.22, train_len= 169.6
# [Iter  122] train_reward= -174.99, train_len= 172.1
# [Iter  123] train_reward= -182.21, train_len= 173.4
# [Iter  124] train_reward= -184.06, train_len= 173.8
# [Iter  125] train_reward= -182.16, train_len= 172.9
# [Iter  126] train_reward= -181.49, train_len= 173.6
# [Iter  127] train_reward= -177.79, train_len= 167.8
# [Iter  128] train_reward= -174.62, train_len= 169.8
# [Iter  129] train_reward= -169.12, train_len= 167.5
# [Iter  130] train_reward= -169.26, train_len= 166.2 | eval_return= -253.04, eval_len= 196.8
# [Iter  131] train_reward= -161.78, train_len= 168.3
# [Iter  132] train_reward= -156.78, train_len= 168.7
# [Iter  133] train_reward= -160.34, train_len= 169.8
# [Iter  134] train_reward= -154.50, train_len= 164.5
# [Iter  135] train_reward= -155.29, train_len= 163.9
# [Iter  136] train_reward= -159.71, train_len= 163.9
# [Iter  137] train_reward= -150.50, train_len= 158.8
# [Iter  138] train_reward= -149.24, train_len= 156.1
# [Iter  139] train_reward= -150.48, train_len= 159.5
# [Iter  140] train_reward= -149.44, train_len= 157.2 | eval_return= -250.52, eval_len= 200.0
# [Iter  141] train_reward= -158.58, train_len= 166.4
# [Iter  142] train_reward= -163.18, train_len= 174.3
# [Iter  143] train_reward= -164.10, train_len= 172.1
# [Iter  144] train_reward= -160.54, train_len= 172.1
# [Iter  145] train_reward= -153.17, train_len= 164.6
# [Iter  146] train_reward= -151.97, train_len= 162.3
# [Iter  147] train_reward= -144.65, train_len= 159.4
# [Iter  148] train_reward= -146.69, train_len= 162.5
# [Iter  149] train_reward= -141.95, train_len= 158.4
# [Iter  150] train_reward= -148.74, train_len= 163.9 | eval_return= -229.03, eval_len= 198.6
# [Iter  151] train_reward= -150.18, train_len= 167.2
# [Iter  152] train_reward= -158.25, train_len= 169.8
# [Iter  153] train_reward= -163.49, train_len= 171.5
# [Iter  154] train_reward= -151.70, train_len= 162.6
# [Iter  155] train_reward= -153.33, train_len= 165.0
# [Iter  156] train_reward= -145.65, train_len= 162.9
# [Iter  157] train_reward= -139.83, train_len= 159.3
# [Iter  158] train_reward= -147.39, train_len= 164.5
# [Iter  159] train_reward= -153.90, train_len= 164.4
# [Iter  160] train_reward= -160.88, train_len= 168.5 | eval_return= -277.71, eval_len= 191.0
# [Iter  161] train_reward= -163.62, train_len= 173.0
# [Iter  162] train_reward= -162.69, train_len= 171.1
# [Iter  163] train_reward= -158.07, train_len= 167.5
# [Iter  164] train_reward= -159.80, train_len= 168.2
# [Iter  165] train_reward= -161.11, train_len= 169.0
# [Iter  166] train_reward= -155.05, train_len= 164.9
# [Iter  167] train_reward= -155.00, train_len= 167.4
# [Iter  168] train_reward= -149.12, train_len= 166.5
# [Iter  169] train_reward= -145.38, train_len= 161.1
# [Iter  170] train_reward= -134.04, train_len= 153.6 | eval_return= -239.83, eval_len= 191.3
# [Iter  171] train_reward= -138.13, train_len= 155.0
# [Iter  172] train_reward= -142.29, train_len= 156.4
# [Iter  173] train_reward= -146.69, train_len= 159.2
# [Iter  174] train_reward= -151.03, train_len= 162.3
# [Iter  175] train_reward= -153.22, train_len= 163.9
# [Iter  176] train_reward= -152.41, train_len= 163.8
# [Iter  177] train_reward= -143.77, train_len= 158.3
# [Iter  178] train_reward= -148.94, train_len= 162.5
# [Iter  179] train_reward= -147.99, train_len= 164.6
# [Iter  180] train_reward= -146.02, train_len= 162.6 | eval_return= -256.99, eval_len= 184.1
# [Iter  181] train_reward= -150.70, train_len= 163.9
# [Iter  182] train_reward= -149.26, train_len= 160.2
# [Iter  183] train_reward= -146.55, train_len= 156.4
# [Iter  184] train_reward= -148.89, train_len= 159.6
# [Iter  185] train_reward= -135.88, train_len= 155.3
# [Iter  186] train_reward= -137.44, train_len= 156.5
# [Iter  187] train_reward= -134.17, train_len= 154.1
# [Iter  188] train_reward= -136.93, train_len= 153.4
# [Iter  189] train_reward= -139.10, train_len= 153.9
# [Iter  190] train_reward= -148.16, train_len= 161.1 | eval_return= -224.83, eval_len= 200.0
# [Iter  191] train_reward= -145.61, train_len= 161.9
# [Iter  192] train_reward= -143.99, train_len= 162.1
# [Iter  193] train_reward= -148.12, train_len= 165.5
# [Iter  194] train_reward= -140.17, train_len= 158.7
# [Iter  195] train_reward= -146.83, train_len= 160.7
# [Iter  196] train_reward= -146.67, train_len= 159.6
# [Iter  197] train_reward= -141.65, train_len= 154.4
# [Iter  198] train_reward= -141.62, train_len= 156.8
# [Iter  199] train_reward= -147.63, train_len= 160.8
# [Iter  200] train_reward= -151.91, train_len= 162.0 | eval_return= -231.93, eval_len= 190.4

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_hist = pd.DataFrame(train_history)

plt.figure()
plt.plot(df_hist["iter"], df_hist["train_reward"], label="train reward")
plt.xlabel("Iteration")
plt.ylabel("Episode return")
plt.legend()
plt.title("Frog Transformer PPO training Training Reward")
plt.show()

# %%
plt.figure()
plt.plot(df_hist["iter"], df_hist["eval_return"], label="eval return")
plt.xlabel("Iteration")
plt.ylabel("Evaluation return")
plt.legend()
plt.title("Frog Transformer PPO training Evaluation Return")
plt.show()
