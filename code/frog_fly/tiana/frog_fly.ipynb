# %% [markdown]
# # Frog–Fly 3D Reinforcement Learning Environment (PPO)
#
# This environment simulates a frog navigating a bounded 3D space to catch a fly.
# The agent observes continuous-valued states, produces continuous 3D actions, and learns using PPO.
#
# ---
#
# ### Environment Definition
#
# $$
# \mathcal{S} = \{(x,y,z) \mid x,y,z \in [-1,1]\}
# $$
#
# At timestep \(t\):
#
# $$
# \mathbf{p}^{(t)}_f \in \mathcal{S}, \qquad
# \mathbf{p}^{(t)}_{\text{fly}} \in \mathcal{S}
# $$
#
# ---
#
# ### Agent Dynamics
#
# Action:
#
# $$
# \mathbf{a}_t \in [-1,1]^3
# $$
#
# Frog motion:
#
# $$
# \mathbf{p}^{(t+1)}_f =
# \mathrm{clip}\!\left(\mathbf{p}^{(t)}_f + \alpha \cdot \mathbf{a}_t,\,
# [-1,1]^3\right)
# $$
#
# Fly motion (stochastic):
#
# $$
# \mathbf{p}^{(t+1)}_{\text{fly}}=
# \mathrm{clip}\!\left(
# \mathbf{p}^{(t)}_{\text{fly}} +
# v_{\text{fly}}\cdot\frac{\epsilon}{\|\epsilon\|},\,
# [-1,1]^3\right),
# \qquad
# \epsilon\sim\mathcal{N}(0,I)
# $$
#
# ---
#
# ### Observation Space
#
# $$
# \mathbf{s}_t =
# [
# \mathbf{p}^{(t)}_f,\,
# \mathbf{p}^{(t)}_{\text{fly}},\,
# \mathbf{p}^{(t)}_{\text{fly}}-\mathbf{p}^{(t)}_f,\,
# PE(\mathbf{p}^{(t)}_f),\,
# PE(\mathbf{p}^{(t)}_{\text{fly}})
# ]
# $$
#
# Positional encoding:
#
# $$
# PE(\mathbf{p}) =
# [
# \sin(\omega_k x),\cos(\omega_k x),\;
# \sin(\omega_k y),\cos(\omega_k y),\;
# \sin(\omega_k z),\cos(\omega_k z)
# ]_{k=1}^{K}
# $$
#
# ---
#
# ### Action Space
#
# $$
# \mathcal{A} = [-1,1]^3
# $$
#
# The policy outputs a continuous displacement vector for movement.
#
# ---
#
# ### Reward Function
#
# Distance:
#
# $$
# d_t = \|\mathbf{p}^{(t)}_{\text{fly}} - \mathbf{p}^{(t)}_{f}\|
# $$
#
# Reward shaping:
#
# $$
# r_t =
# \begin{cases}
# -\,d_t, & \text{not caught},\\[6pt]
# 10 - d_t, & \text{if } d_t < \delta.
# \end{cases}
# $$
#
# Goal → minimize distance + catch fly efficiently.
#
# ---
#
# # PPO Objective
#
# Probability ratio:
#
# $$
# r_t(\theta) =
# \dfrac{\pi_\theta(a_t\,|\,s_t)}
#       {\pi_{\theta_{\text{old}}}(a_t\,|\,s_t)}
# $$
#
# Advantage:
#
# $$
# A_t =
# \sum_{k=0}^{T-t} \gamma^k r_{t+k} -
# V_\phi(s_t)
# $$
#
# Clipped surrogate:
#
# $$
# J(\theta) =
# \mathbb{E}_t \Big[
# \min(
# r_t(\theta)A_t,\,
# \text{clip}(r_t(\theta),1-\epsilon,1+\epsilon)A_t
# )\Big]
# $$
#
# Value loss:
#
# $$
# L_V(\phi)=\mathbb{E}_t[(V_\phi(s_t)-R_t)^2]
# $$
#
# Final optimization:
#
# $$
# \max_\theta J(\theta), \qquad \min_\phi L_V(\phi)
# $$
#
# ---
#
# ### MDP Summary
#
# | Element | Definition |
# |---|---|
# | State \(s_t\) | positions + relative vector + positional encodings |
# | Action \(a_t\) | continuous 3D movement vector |
# | Reward \(r_t\) | shaped distance + capture bonus |
# | Goal | catch fly efficiently |
# | Algorithm | PPO |

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 (needed for 3D)

import gymnasium as gym
from gymnasium import spaces

import ray
from ray.rllib.algorithms.ppo import PPOConfig

# %%
def positional_encoding_3d(pos, num_freqs=4, max_freq=10.0):
    """
    pos: np.array shape (3,) with (x, y, z) in [-space_size, space_size].
    Returns: encoding vector of shape (3 * 2 * num_freqs,)
    """
    pos = np.asarray(pos, dtype=np.float32)
    assert pos.shape == (3,)

    freqs = np.linspace(1.0, max_freq, num_freqs)
    enc = []
    for coord in pos:            # x, y, z
        for f in freqs:
            enc.append(np.sin(f * coord))
            enc.append(np.cos(f * coord))
    return np.array(enc, dtype=np.float32)


class FrogFly3DEnv(gym.Env):
    """
    3D continuous environment:
    - Frog (agent) moves to catch a moving fly.
    - Observations: positions + relative vector + positional encodings.
    """
    metadata = {"render_modes": ["human"], "render_fps": 30}

    def __init__(self, config=None):
        super().__init__()

        if config is None:
            config = {}

        self.space_size = float(config.get("space_size", 1.0))
        self.step_size = float(config.get("step_size", 0.1))
        self.fly_speed = float(config.get("fly_speed", 0.05))
        self.catch_radius = float(config.get("catch_radius", 0.15))
        self.max_steps = int(config.get("max_steps", 200))
        self.num_freqs = int(config.get("num_freqs", 4))
        self.use_positional_encodings = bool(
            config.get("use_positional_encodings", True)
        )

        # Action = 3D movement in [-1, 1]^3
        self.action_space = spaces.Box(
            low=-1.0, high=1.0, shape=(3,), dtype=np.float32
        )

        # Observation components
        # frog_pos (3) + fly_pos (3) + rel (3) = 9
        base_dim = 9
        if self.use_positional_encodings:
            pe_dim = 3 * 2 * self.num_freqs  # per position
            obs_dim = base_dim + 2 * pe_dim
        else:
            obs_dim = base_dim

        self.observation_space = spaces.Box(
            low=-5.0, high=5.0, shape=(obs_dim,), dtype=np.float32
        )

        self.frog_pos = None
        self.fly_pos = None
        self.steps = 0

    # ---------- Helpers ----------

    def _sample_position(self):
        return np.random.uniform(
            low=-self.space_size,
            high=self.space_size,
            size=(3,),
        ).astype(np.float32)

    def _clip_position(self, pos):
        return np.clip(pos, -self.space_size, self.space_size).astype(np.float32)

    def _get_obs(self):
        rel = self.fly_pos - self.frog_pos
        parts = [self.frog_pos, self.fly_pos, rel]

        if self.use_positional_encodings:
            frog_pe = positional_encoding_3d(self.frog_pos, self.num_freqs)
            fly_pe = positional_encoding_3d(self.fly_pos, self.num_freqs)
            parts.extend([frog_pe, fly_pe])

        return np.concatenate(parts, axis=0).astype(np.float32)

    def _get_distance(self):
        return float(np.linalg.norm(self.fly_pos - self.frog_pos))

    # ---------- Gymnasium API ----------

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.steps = 0
        self.frog_pos = self._sample_position()
        self.fly_pos = self._sample_position()

        obs = self._get_obs()
        info = {}
        return obs, info

    def step(self, action):
        self.steps += 1

        action = np.asarray(action, dtype=np.float32)
        action = np.clip(action, -1.0, 1.0)

        # Frog moves
        self.frog_pos = self.frog_pos + self.step_size * action
        self.frog_pos = self._clip_position(self.frog_pos)

        # Fly moves randomly
        fly_dir = np.random.normal(size=(3,)).astype(np.float32)
        fly_dir /= np.linalg.norm(fly_dir) + 1e-8
        self.fly_pos = self.fly_pos + self.fly_speed * fly_dir
        self.fly_pos = self._clip_position(self.fly_pos)

        dist = self._get_distance()
        caught = dist < self.catch_radius

        # Reward shaping: closer is better + bonus for catch
        reward = -dist
        if caught:
            reward += 10.0

        terminated = caught
        truncated = self.steps >= self.max_steps

        obs = self._get_obs()
        info = {"distance": dist, "caught": caught}

        return obs, reward, terminated, truncated, info

    def render(self):
        print(
            f"Step {self.steps} | "
            f"Frog: {self.frog_pos} | Fly: {self.fly_pos} | "
            f"Dist: {self._get_distance():.3f}"
        )

    def close(self):
        pass

# %%
ray.shutdown()
ray.init(ignore_reinit_error=True)

env_config = {
    "space_size": 1.0,
    "step_size": 0.1,
    "fly_speed": 0.05,
    "catch_radius": 0.15,
    "max_steps": 200,
    "num_freqs": 4,
    "use_positional_encodings": True,
}

config = (
    PPOConfig()
    # Pass the *class* here
    .environment(env=FrogFly3DEnv, env_config=env_config)
    .framework("torch")
    .resources(num_gpus=0)
    .training(
        model={
            "fcnet_hiddens": [256, 256],
            "fcnet_activation": "tanh",
        },
        gamma=0.99,
        lr=3e-4,
    )
)

algo = config.build()
print("Algo built OK")
# Out:
# 2025-12-02 22:46:24,077	INFO worker.py:2023 -- Started a local Ray instance.
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# 2025-12-02 22:46:24,934	WARNING 73488542.py:30 -- DeprecationWarning: `build` has been deprecated. Use `AlgorithmConfig.build_algo` instead. This will raise an error in the future!
# 2025-12-02 22:46:24,936	WARNING algorithm_config.py:5058 -- You are running PPO on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# [2025-12-02 22:46:25,008 E 11711 65199412] core_worker.cc:2223: Actor with class name: 'SingleAgentEnvRunner' and ID: '21b29fadce3bffb12ab06f6901000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (SingleAgentEnvRunner pid=11801) DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# 2025-12-02 22:46:27,073	WARNING rl_module.py:459 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# 2025-12-02 22:46:27,652	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Algo built OK

# %%
num_iterations = 200

mean_rewards = []
mean_lengths = []

for i in range(num_iterations):
    result = algo.train()

    # Newer RLlib: metrics under "env_runners"
    if "env_runners" in result:
        env_metrics = result["env_runners"]
        mean_r = env_metrics.get("episode_return_mean", np.nan)
        mean_l = env_metrics.get("episode_len_mean", np.nan)
    else:
        # Older RLlib: metrics at top level
        mean_r = result.get("episode_reward_mean", np.nan)
        mean_l = result.get("episode_len_mean", np.nan)

    mean_rewards.append(mean_r)
    mean_lengths.append(mean_l)

    print(
        f"Iter {i+1:03d} | "
        f"reward_mean = {mean_r:.3f} | "
        f"len_mean = {mean_l:.2f}"
    )
# Out:
# Iter 001 | reward_mean = -305.142 | len_mean = 192.40
# Iter 002 | reward_mean = -289.389 | len_mean = 190.63
# Iter 003 | reward_mean = -266.006 | len_mean = 189.44
# Iter 004 | reward_mean = -243.925 | len_mean = 191.82
# (pid=gcs_server) [2025-12-02 22:46:53,397 E 11789 65205530] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-02 22:46:54,087 E 11793 65205642] (raylet) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# Iter 005 | reward_mean = -245.236 | len_mean = 196.20
# (SingleAgentEnvRunner pid=11801) [2025-12-02 22:46:54,779 E 11801 65205887] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-02 22:46:54,959 E 11711 65205693] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# Iter 006 | reward_mean = -250.024 | len_mean = 191.56
# Iter 007 | reward_mean = -239.565 | len_mean = 190.54
# Iter 008 | reward_mean = -237.807 | len_mean = 195.10
# Iter 009 | reward_mean = -233.218 | len_mean = 189.66
# Iter 010 | reward_mean = -239.409 | len_mean = 190.02
# Iter 011 | reward_mean = -213.530 | len_mean = 184.44
# Iter 012 | reward_mean = -212.955 | len_mean = 189.80
# Iter 013 | reward_mean = -210.973 | len_mean = 182.94
# Iter 014 | reward_mean = -201.514 | len_mean = 177.44
# Iter 015 | reward_mean = -214.980 | len_mean = 183.12
# Iter 016 | reward_mean = -200.013 | len_mean = 174.08
# Iter 017 | reward_mean = -193.976 | len_mean = 179.50
# Iter 018 | reward_mean = -186.176 | len_mean = 178.68
# Iter 019 | reward_mean = -204.270 | len_mean = 184.20
# Iter 020 | reward_mean = -214.652 | len_mean = 184.66
# Iter 021 | reward_mean = -228.122 | len_mean = 189.00
# Iter 022 | reward_mean = -206.256 | len_mean = 185.66
# Iter 023 | reward_mean = -163.031 | len_mean = 173.60
# Iter 024 | reward_mean = -171.490 | len_mean = 171.30
# Iter 025 | reward_mean = -191.565 | len_mean = 182.90
# Iter 026 | reward_mean = -201.732 | len_mean = 187.82
# Iter 027 | reward_mean = -176.037 | len_mean = 175.56
# Iter 028 | reward_mean = -171.138 | len_mean = 173.76
# Iter 029 | reward_mean = -173.027 | len_mean = 181.58
# Iter 030 | reward_mean = -164.478 | len_mean = 182.92
# Iter 031 | reward_mean = -169.347 | len_mean = 177.92
# Iter 032 | reward_mean = -152.953 | len_mean = 172.82
# Iter 033 | reward_mean = -141.574 | len_mean = 167.14
# Iter 034 | reward_mean = -143.730 | len_mean = 172.20
# Iter 035 | reward_mean = -154.236 | len_mean = 173.20
# Iter 036 | reward_mean = -168.341 | len_mean = 176.96
# Iter 037 | reward_mean = -161.358 | len_mean = 174.42
# Iter 038 | reward_mean = -150.219 | len_mean = 169.04
# Iter 039 | reward_mean = -150.605 | len_mean = 173.38
# Iter 040 | reward_mean = -133.568 | len_mean = 156.66
# Iter 041 | reward_mean = -117.070 | len_mean = 150.50
# Iter 042 | reward_mean = -124.070 | len_mean = 150.94
# Iter 043 | reward_mean = -127.950 | len_mean = 154.24
# Iter 044 | reward_mean = -122.890 | len_mean = 154.80
# Iter 045 | reward_mean = -123.450 | len_mean = 151.72
# Iter 046 | reward_mean = -111.750 | len_mean = 142.46
# Iter 047 | reward_mean = -117.893 | len_mean = 144.36
# Iter 048 | reward_mean = -131.864 | len_mean = 157.56
# Iter 049 | reward_mean = -144.799 | len_mean = 168.60
# Iter 050 | reward_mean = -137.542 | len_mean = 164.60
# Iter 051 | reward_mean = -119.457 | len_mean = 153.34
# Iter 052 | reward_mean = -135.525 | len_mean = 160.80
# Iter 053 | reward_mean = -135.380 | len_mean = 161.70
# Iter 054 | reward_mean = -127.762 | len_mean = 159.38
# Iter 055 | reward_mean = -135.292 | len_mean = 159.88
# Iter 056 | reward_mean = -127.622 | len_mean = 154.26
# Iter 057 | reward_mean = -119.653 | len_mean = 153.02
# Iter 058 | reward_mean = -113.120 | len_mean = 145.62
# Iter 059 | reward_mean = -112.014 | len_mean = 138.36
# Iter 060 | reward_mean = -114.969 | len_mean = 148.44
# Iter 061 | reward_mean = -112.137 | len_mean = 151.38
# Iter 062 | reward_mean = -116.452 | len_mean = 149.42
# Iter 063 | reward_mean = -125.908 | len_mean = 161.80
# Iter 064 | reward_mean = -123.728 | len_mean = 167.80
# Iter 065 | reward_mean = -117.820 | len_mean = 158.18
# Iter 066 | reward_mean = -120.868 | len_mean = 156.06
# Iter 067 | reward_mean = -124.361 | len_mean = 158.12
# Iter 068 | reward_mean = -107.235 | len_mean = 144.46
# Iter 069 | reward_mean = -95.793 | len_mean = 129.82
# Iter 070 | reward_mean = -111.303 | len_mean = 143.26
# Iter 071 | reward_mean = -121.172 | len_mean = 157.04
# Iter 072 | reward_mean = -117.327 | len_mean = 150.30
# Iter 073 | reward_mean = -120.407 | len_mean = 156.50
# Iter 074 | reward_mean = -100.168 | len_mean = 139.70
# Iter 075 | reward_mean = -92.728 | len_mean = 132.24
# Iter 076 | reward_mean = -99.155 | len_mean = 143.58
# Iter 077 | reward_mean = -101.255 | len_mean = 144.12
# Iter 078 | reward_mean = -108.999 | len_mean = 146.30
# Iter 079 | reward_mean = -106.436 | len_mean = 148.36
# Iter 080 | reward_mean = -102.222 | len_mean = 142.22
# Iter 081 | reward_mean = -104.718 | len_mean = 142.26
# Iter 082 | reward_mean = -95.539 | len_mean = 127.42
# Iter 083 | reward_mean = -85.333 | len_mean = 126.36
# Iter 084 | reward_mean = -99.765 | len_mean = 143.46
# Iter 085 | reward_mean = -105.064 | len_mean = 144.64
# Iter 086 | reward_mean = -93.317 | len_mean = 130.02
# Iter 087 | reward_mean = -88.676 | len_mean = 126.48
# Iter 088 | reward_mean = -84.941 | len_mean = 130.28
# Iter 089 | reward_mean = -85.244 | len_mean = 136.20
# Iter 090 | reward_mean = -80.917 | len_mean = 128.66
# Iter 091 | reward_mean = -86.428 | len_mean = 130.54
# Iter 092 | reward_mean = -87.342 | len_mean = 132.38
# Iter 093 | reward_mean = -91.468 | len_mean = 143.84
# Iter 094 | reward_mean = -101.182 | len_mean = 153.80
# Iter 095 | reward_mean = -85.882 | len_mean = 132.26
# Iter 096 | reward_mean = -84.146 | len_mean = 123.64
# Iter 097 | reward_mean = -85.814 | len_mean = 128.38
# Iter 098 | reward_mean = -74.880 | len_mean = 120.96
# Iter 099 | reward_mean = -80.380 | len_mean = 123.38
# Iter 100 | reward_mean = -83.996 | len_mean = 134.48
# Iter 101 | reward_mean = -73.456 | len_mean = 123.26
# Iter 102 | reward_mean = -73.139 | len_mean = 118.08
# Iter 103 | reward_mean = -70.022 | len_mean = 114.58
# Iter 104 | reward_mean = -64.052 | len_mean = 101.54
# Iter 105 | reward_mean = -79.593 | len_mean = 124.20
# Iter 106 | reward_mean = -67.591 | len_mean = 112.48
# Iter 107 | reward_mean = -80.889 | len_mean = 125.40
# Iter 108 | reward_mean = -80.597 | len_mean = 124.94
# Iter 109 | reward_mean = -83.296 | len_mean = 134.38
# Iter 110 | reward_mean = -76.859 | len_mean = 126.54
# Iter 111 | reward_mean = -69.581 | len_mean = 121.44
# Iter 112 | reward_mean = -76.900 | len_mean = 126.54
# Iter 113 | reward_mean = -78.437 | len_mean = 119.30
# Iter 114 | reward_mean = -75.019 | len_mean = 126.28
# Iter 115 | reward_mean = -74.735 | len_mean = 122.22
# Iter 116 | reward_mean = -58.098 | len_mean = 104.92
# Iter 117 | reward_mean = -75.955 | len_mean = 127.80
# Iter 118 | reward_mean = -79.364 | len_mean = 131.76
# Iter 119 | reward_mean = -76.978 | len_mean = 129.14
# Iter 120 | reward_mean = -66.268 | len_mean = 113.24
# Iter 121 | reward_mean = -73.813 | len_mean = 124.44
# Iter 122 | reward_mean = -75.712 | len_mean = 122.74
# Iter 123 | reward_mean = -64.475 | len_mean = 114.28
# Iter 124 | reward_mean = -59.224 | len_mean = 103.48
# Iter 125 | reward_mean = -67.350 | len_mean = 112.42
# Iter 126 | reward_mean = -75.879 | len_mean = 120.32
# Iter 127 | reward_mean = -69.919 | len_mean = 117.98
# Iter 128 | reward_mean = -61.558 | len_mean = 111.90
# Iter 129 | reward_mean = -57.607 | len_mean = 108.40
# Iter 130 | reward_mean = -65.437 | len_mean = 114.06
# Iter 131 | reward_mean = -67.948 | len_mean = 115.04
# Iter 132 | reward_mean = -71.879 | len_mean = 122.28
# Iter 133 | reward_mean = -73.641 | len_mean = 123.38
# Iter 134 | reward_mean = -74.567 | len_mean = 120.92
# Iter 135 | reward_mean = -70.783 | len_mean = 113.88
# Iter 136 | reward_mean = -72.537 | len_mean = 120.66
# Iter 137 | reward_mean = -64.491 | len_mean = 117.12
# Iter 138 | reward_mean = -61.850 | len_mean = 112.72
# Iter 139 | reward_mean = -65.016 | len_mean = 112.90
# Iter 140 | reward_mean = -65.375 | len_mean = 115.72
# Iter 141 | reward_mean = -62.800 | len_mean = 106.12
# Iter 142 | reward_mean = -54.362 | len_mean = 100.52
# Iter 143 | reward_mean = -53.217 | len_mean = 106.40
# Iter 144 | reward_mean = -57.487 | len_mean = 110.84
# Iter 145 | reward_mean = -65.328 | len_mean = 110.30
# Iter 146 | reward_mean = -66.388 | len_mean = 113.50
# Iter 147 | reward_mean = -57.768 | len_mean = 102.68
# Iter 148 | reward_mean = -54.421 | len_mean = 105.68
# Iter 149 | reward_mean = -55.223 | len_mean = 103.40
# Iter 150 | reward_mean = -63.977 | len_mean = 114.04
# Iter 151 | reward_mean = -62.238 | len_mean = 107.48
# Iter 152 | reward_mean = -61.225 | len_mean = 114.18
# Iter 153 | reward_mean = -59.908 | len_mean = 112.54
# Iter 154 | reward_mean = -58.391 | len_mean = 109.00
# Iter 155 | reward_mean = -56.536 | len_mean = 98.80
# Iter 156 | reward_mean = -58.898 | len_mean = 106.46
# Iter 157 | reward_mean = -64.785 | len_mean = 110.54
# Iter 158 | reward_mean = -61.129 | len_mean = 110.18
# Iter 159 | reward_mean = -69.875 | len_mean = 120.02
# Iter 160 | reward_mean = -53.845 | len_mean = 101.52
# Iter 161 | reward_mean = -57.594 | len_mean = 109.00
# Iter 162 | reward_mean = -56.446 | len_mean = 106.98
# Iter 163 | reward_mean = -65.534 | len_mean = 117.38
# Iter 164 | reward_mean = -62.175 | len_mean = 115.34
# Iter 165 | reward_mean = -57.994 | len_mean = 105.38
# Iter 166 | reward_mean = -66.715 | len_mean = 116.24
# Iter 167 | reward_mean = -51.124 | len_mean = 96.16
# Iter 168 | reward_mean = -60.600 | len_mean = 107.96
# Iter 169 | reward_mean = -62.487 | len_mean = 111.94
# Iter 170 | reward_mean = -46.270 | len_mean = 90.30
# Iter 171 | reward_mean = -59.329 | len_mean = 110.28
# Iter 172 | reward_mean = -52.530 | len_mean = 103.60
# Iter 173 | reward_mean = -49.438 | len_mean = 97.50
# Iter 174 | reward_mean = -53.351 | len_mean = 103.28
# Iter 175 | reward_mean = -59.045 | len_mean = 109.14
# Iter 176 | reward_mean = -54.550 | len_mean = 103.22
# Iter 177 | reward_mean = -57.641 | len_mean = 112.32
# Iter 178 | reward_mean = -60.367 | len_mean = 111.10
# Iter 179 | reward_mean = -53.110 | len_mean = 99.02
# Iter 180 | reward_mean = -51.296 | len_mean = 95.06
# Iter 181 | reward_mean = -53.620 | len_mean = 104.76
# Iter 182 | reward_mean = -62.490 | len_mean = 123.42
# Iter 183 | reward_mean = -57.896 | len_mean = 111.06
# Iter 184 | reward_mean = -59.608 | len_mean = 110.50
# Iter 185 | reward_mean = -44.845 | len_mean = 87.78
# Iter 186 | reward_mean = -42.216 | len_mean = 85.64
# Iter 187 | reward_mean = -51.449 | len_mean = 106.40
# Iter 188 | reward_mean = -45.674 | len_mean = 98.62
# Iter 189 | reward_mean = -56.631 | len_mean = 103.14
# Iter 190 | reward_mean = -51.434 | len_mean = 95.84
# Iter 191 | reward_mean = -54.265 | len_mean = 103.04
# Iter 192 | reward_mean = -50.832 | len_mean = 99.44
# Iter 193 | reward_mean = -49.490 | len_mean = 93.32
# Iter 194 | reward_mean = -56.972 | len_mean = 106.80
# Iter 195 | reward_mean = -43.201 | len_mean = 93.24
# Iter 196 | reward_mean = -45.334 | len_mean = 92.40
# Iter 197 | reward_mean = -52.354 | len_mean = 104.16
# Iter 198 | reward_mean = -42.620 | len_mean = 91.40
# Iter 199 | reward_mean = -43.470 | len_mean = 92.66
# Iter 200 | reward_mean = -50.365 | len_mean = 100.76

# %%
import torch

def rollout_trajectory(env, policy_fn, max_steps=200):
    """
    Run one episode and record frog & fly positions.
    policy_fn: function(obs) -> action (np.array of shape (3,))
    """
    obs, info = env.reset()
    frog_traj = [env.frog_pos.copy()]
    fly_traj = [env.fly_pos.copy()]

    for t in range(max_steps):
        action = policy_fn(obs)
        obs, reward, terminated, truncated, info = env.step(action)

        frog_traj.append(env.frog_pos.copy())
        fly_traj.append(env.fly_pos.copy())

        if terminated or truncated:
            break

    return np.array(frog_traj), np.array(fly_traj)


def random_policy(obs, action_space):
    return action_space.sample()


def trained_policy_factory(algo):
    """
    Build a policy(obs) function that uses the NEW RLlib API stack.

    It:
      1. Calls rl_module.forward_inference(...)
      2. Uses the module's inference distribution class
      3. Samples a deterministic action for a single observation
    """
    # Single-agent PPO: this returns the default RLModule
    rl_module = algo.get_module()

    # RLlib picks a default Distribution class from the action space
    # (TorchDiagGaussian for Box, TorchCategorical for Discrete, etc.)
    dist_cls = rl_module.get_inference_action_dist_cls()

    def policy(obs):
        # Ensure obs is float32 and batched
        obs_np = np.asarray(obs, dtype=np.float32)
        batch = {"obs": torch.from_numpy(obs_np).unsqueeze(0)}

        with torch.no_grad():
            out = rl_module.forward_inference(batch)

        # --- Case 1: some modules might already return final actions ---
        if "actions" in out:
            actions = out["actions"].detach().cpu().numpy()
            return actions[0]

        # --- Case 2: PPO returns action_dist_inputs logits ---
        logits = out["action_dist_inputs"]

        # Build a Distribution from logits, then make it deterministic
        dist = dist_cls.from_logits(logits)
        det_dist = dist.to_deterministic()

        # Sample a (deterministic) action, shape: [batch, action_dim]
        actions = det_dist.sample().detach().cpu().numpy()
        return actions[0]

    return policy

def make_3d_gif(frog_traj, fly_traj, out_path, title=""):
    """
    frog_traj, fly_traj: arrays of shape (T, 3)
    Saves a 3D animated GIF at out_path.
    """
    T = frog_traj.shape[0]
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, projection='3d')

    lim = 1.0
    ax.set_xlim(-lim, lim)
    ax.set_ylim(-lim, lim)
    ax.set_zlim(-lim, lim)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.set_title(title)

    def update(frame):
        ax.clear()
        ax.set_xlim(-lim, lim)
        ax.set_ylim(-lim, lim)
        ax.set_zlim(-lim, lim)
        ax.set_xlabel("X")
        ax.set_ylabel("Y")
        ax.set_zlabel("Z")
        ax.set_title(title)

        f = frog_traj[:frame+1]
        fl = fly_traj[:frame+1]

        ax.plot(f[:, 0], f[:, 1], f[:, 2], lw=2, color="green", label="Frog path")
        ax.plot(fl[:, 0], fl[:, 1], fl[:, 2], lw=2, color="red", label="Fly path")
        ax.scatter(f[-1, 0], f[-1, 1], f[-1, 2], s=50, color="green")
        ax.scatter(fl[-1, 0], fl[-1, 1], fl[-1, 2], s=50, color="red")

        ax.legend(loc="upper left")
        return []

    anim = animation.FuncAnimation(
        fig, update, frames=T, interval=50, blit=False
    )

    writer = animation.PillowWriter(fps=20)
    anim.save(out_path, writer=writer)
    plt.close(fig)

# %%
# Fresh env for recording
record_env = FrogFly3DEnv(env_config)

# BEFORE: random frog vs fly
frog_before, fly_before = rollout_trajectory(
    record_env,
    policy_fn=lambda obs: random_policy(obs, record_env.action_space),
    max_steps=200,
)
make_3d_gif(
    frog_before,
    fly_before,
    out_path="frog_fly_before.gif",
    title="Random Frog vs Fly (Before RL)",
)

# AFTER: PPO-trained frog vs fly
trained_policy = trained_policy_factory(algo)
frog_after, fly_after = rollout_trajectory(
    record_env,
    policy_fn=trained_policy,
    max_steps=200,
)
make_3d_gif(
    frog_after,
    fly_after,
    out_path="frog_fly_after.gif",
    title="PPO-Trained Frog vs Fly (After RL)",
)

print("Saved GIFs: frog_fly_before.gif, frog_fly_after.gif")
# Out:
# Saved GIFs: frog_fly_before.gif, frog_fly_after.gif

# %%
iters = np.arange(1, len(mean_rewards) + 1)

plt.figure(figsize=(10, 4))
plt.plot(iters, mean_rewards, label="Mean Episode Reward")
plt.xlabel("Training Iteration")
plt.ylabel("Reward")
plt.title("FrogFly3D PPO: Reward Curve")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
plt.plot(iters, mean_lengths, label="Mean Episode Length")
plt.xlabel("Training Iteration")
plt.ylabel("Episode Length (steps)")
plt.title("FrogFly3D PPO: Episode Length Curve")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# SAC on FrogFly3DEnv (continuous)

# %%
from ray.rllib.algorithms.registry import ALGORITHMS

print(list(ALGORITHMS.keys()))
# Out:
# ['APPO', 'BC', 'CQL', 'DQN', 'DreamerV3', 'IMPALA', 'IQL', 'MARWIL', 'PPO', 'SAC']

# %%
import ray
from ray.rllib.algorithms.sac import SACConfig

ray.shutdown()
ray.init(ignore_reinit_error=True)

env_config = {
    "space_size": 1.0,
    "step_size": 0.1,
    "fly_speed": 0.05,
    "catch_radius": 0.15,
    "max_steps": 200,
    "num_freqs": 4,
    "use_positional_encodings": True,
}

sac_config = (
    SACConfig()
    .environment(env=FrogFly3DEnv, env_config=env_config)
    .framework("torch")
    .resources(num_gpus=0)
    .training(
        gamma=0.99,
        # reuse roughly the same MLP as PPO
        model={
            "fcnet_hiddens": [256, 256],
            "fcnet_activation": "tanh",
        },
    )
)

sac_algo = sac_config.build()
print("SAC algo built OK")
# Out:
# 2025-12-02 23:06:15,378	INFO worker.py:2023 -- Started a local Ray instance.
# 2025-12-02 23:06:15,960	WARNING algorithm_config.py:5058 -- You are running SAC on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# 2025-12-02 23:06:15,960	WARNING sac.py:491 -- You are running SAC on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2025-12-02 23:06:16,432	WARNING sac.py:491 -- You are running SAC on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# 2025-12-02 23:06:16,474	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# SAC algo built OK

# %%
num_sac_iters = 200

sac_mean_rewards = []
sac_mean_lengths = []

for i in range(num_sac_iters):
    result = sac_algo.train()

    if "env_runners" in result:
        env_metrics = result["env_runners"]
        mean_r = env_metrics.get("episode_return_mean", float("nan"))
        mean_l = env_metrics.get("episode_len_mean", float("nan"))
    else:
        mean_r = result.get("episode_reward_mean", float("nan"))
        mean_l = result.get("episode_len_mean", float("nan"))

    sac_mean_rewards.append(mean_r)
    sac_mean_lengths.append(mean_l)

    print(
        f"SAC iter {i+1:03d} | "
        f"reward_mean = {mean_r:.3f} | "
        f"len_mean = {mean_l:.2f}"
    )
# Out:
# SAC iter 001 | reward_mean = -243.717 | len_mean = 200.00
# SAC iter 002 | reward_mean = -262.813 | len_mean = 200.00
# SAC iter 003 | reward_mean = -270.512 | len_mean = 200.00
# SAC iter 004 | reward_mean = -258.879 | len_mean = 200.00
# SAC iter 005 | reward_mean = -270.480 | len_mean = 200.00
# SAC iter 006 | reward_mean = -284.820 | len_mean = 200.00
# SAC iter 007 | reward_mean = -253.972 | len_mean = 182.56
# SAC iter 008 | reward_mean = -253.972 | len_mean = 182.56
# (pid=gcs_server) [2025-12-02 23:06:44,686 E 12011 65232737] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# SAC iter 009 | reward_mean = -264.073 | len_mean = 184.30
# (raylet) [2025-12-02 23:06:45,323 E 12015 65232830] (raylet) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (pid=12022) [2025-12-02 23:06:45,833 E 12022 65233103] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-02 23:06:45,978 E 11711 65232880] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# SAC iter 010 | reward_mean = -264.073 | len_mean = 184.30
# SAC iter 011 | reward_mean = -267.789 | len_mean = 185.73
# SAC iter 012 | reward_mean = -267.789 | len_mean = 185.73
# SAC iter 013 | reward_mean = -276.950 | len_mean = 186.92
# SAC iter 014 | reward_mean = -276.950 | len_mean = 186.92
# SAC iter 015 | reward_mean = -265.111 | len_mean = 187.92
# SAC iter 016 | reward_mean = -265.111 | len_mean = 187.92
# SAC iter 017 | reward_mean = -261.118 | len_mean = 188.79
# SAC iter 018 | reward_mean = -261.118 | len_mean = 188.79
# SAC iter 019 | reward_mean = -257.606 | len_mean = 189.53
# SAC iter 020 | reward_mean = -257.606 | len_mean = 189.53
# SAC iter 021 | reward_mean = -240.189 | len_mean = 180.88
# SAC iter 022 | reward_mean = -240.189 | len_mean = 180.88
# SAC iter 023 | reward_mean = -240.161 | len_mean = 181.94
# SAC iter 024 | reward_mean = -240.161 | len_mean = 181.94
# SAC iter 025 | reward_mean = -236.647 | len_mean = 182.89
# SAC iter 026 | reward_mean = -236.647 | len_mean = 182.89
# SAC iter 027 | reward_mean = -232.066 | len_mean = 183.75
# SAC iter 028 | reward_mean = -232.066 | len_mean = 183.75
# SAC iter 029 | reward_mean = -226.932 | len_mean = 184.52
# SAC iter 030 | reward_mean = -226.932 | len_mean = 184.52
# SAC iter 031 | reward_mean = -221.272 | len_mean = 185.23
# SAC iter 032 | reward_mean = -221.272 | len_mean = 185.23
# SAC iter 033 | reward_mean = -207.955 | len_mean = 179.21
# SAC iter 034 | reward_mean = -207.955 | len_mean = 179.21
# SAC iter 035 | reward_mean = -203.436 | len_mean = 179.08
# SAC iter 036 | reward_mean = -203.436 | len_mean = 179.08
# SAC iter 037 | reward_mean = -202.070 | len_mean = 179.88
# SAC iter 038 | reward_mean = -202.070 | len_mean = 179.88
# SAC iter 039 | reward_mean = -198.902 | len_mean = 180.63
# SAC iter 040 | reward_mean = -198.902 | len_mean = 180.63
# SAC iter 041 | reward_mean = -197.320 | len_mean = 181.32
# SAC iter 042 | reward_mean = -197.320 | len_mean = 181.32
# SAC iter 043 | reward_mean = -194.783 | len_mean = 181.97
# SAC iter 044 | reward_mean = -194.783 | len_mean = 181.97
# SAC iter 045 | reward_mean = -192.088 | len_mean = 182.57
# SAC iter 046 | reward_mean = -192.088 | len_mean = 182.57
# SAC iter 047 | reward_mean = -182.174 | len_mean = 177.09
# SAC iter 048 | reward_mean = -182.174 | len_mean = 177.09
# SAC iter 049 | reward_mean = -175.543 | len_mean = 173.35
# SAC iter 050 | reward_mean = -175.543 | len_mean = 173.35
# SAC iter 051 | reward_mean = -172.047 | len_mean = 172.00
# SAC iter 052 | reward_mean = -172.047 | len_mean = 172.00
# SAC iter 053 | reward_mean = -170.797 | len_mean = 172.78
# SAC iter 054 | reward_mean = -170.797 | len_mean = 172.78
# SAC iter 055 | reward_mean = -166.424 | len_mean = 170.71
# SAC iter 056 | reward_mean = -166.424 | len_mean = 170.71
# SAC iter 057 | reward_mean = -159.981 | len_mean = 166.55
# SAC iter 058 | reward_mean = -159.981 | len_mean = 166.55
# SAC iter 059 | reward_mean = -158.186 | len_mean = 167.37
# SAC iter 060 | reward_mean = -154.724 | len_mean = 164.76
# SAC iter 061 | reward_mean = -152.612 | len_mean = 164.37
# SAC iter 062 | reward_mean = -152.612 | len_mean = 164.37
# SAC iter 063 | reward_mean = -147.875 | len_mean = 161.87
# SAC iter 064 | reward_mean = -147.875 | len_mean = 161.87
# SAC iter 065 | reward_mean = -147.615 | len_mean = 162.70
# SAC iter 066 | reward_mean = -147.615 | len_mean = 162.70
# SAC iter 067 | reward_mean = -147.016 | len_mean = 163.49
# SAC iter 068 | reward_mean = -141.505 | len_mean = 159.04
# SAC iter 069 | reward_mean = -139.453 | len_mean = 157.96
# SAC iter 070 | reward_mean = -134.399 | len_mean = 153.60
# SAC iter 071 | reward_mean = -127.443 | len_mean = 146.62
# SAC iter 072 | reward_mean = -126.288 | len_mean = 146.23
# SAC iter 073 | reward_mean = -122.248 | len_mean = 142.16
# SAC iter 074 | reward_mean = -118.766 | len_mean = 139.52
# SAC iter 075 | reward_mean = -113.703 | len_mean = 134.92
# SAC iter 076 | reward_mean = -108.643 | len_mean = 130.12
# SAC iter 077 | reward_mean = -105.655 | len_mean = 126.97
# SAC iter 078 | reward_mean = -98.880 | len_mean = 120.36
# SAC iter 079 | reward_mean = -92.722 | len_mean = 114.03
# SAC iter 080 | reward_mean = -91.582 | len_mean = 112.91
# SAC iter 081 | reward_mean = -89.965 | len_mean = 111.80
# SAC iter 082 | reward_mean = -88.139 | len_mean = 110.52
# SAC iter 083 | reward_mean = -85.647 | len_mean = 108.07
# SAC iter 084 | reward_mean = -83.020 | len_mean = 105.65
# SAC iter 085 | reward_mean = -81.300 | len_mean = 104.05
# SAC iter 086 | reward_mean = -80.780 | len_mean = 104.09
# SAC iter 087 | reward_mean = -78.514 | len_mean = 102.12
# SAC iter 088 | reward_mean = -77.804 | len_mean = 101.73
# SAC iter 089 | reward_mean = -74.953 | len_mean = 98.86
# SAC iter 090 | reward_mean = -72.707 | len_mean = 97.61
# SAC iter 091 | reward_mean = -64.508 | len_mean = 93.02
# SAC iter 092 | reward_mean = -59.968 | len_mean = 89.98
# SAC iter 093 | reward_mean = -52.915 | len_mean = 86.99
# SAC iter 094 | reward_mean = -53.282 | len_mean = 87.53
# SAC iter 095 | reward_mean = -41.713 | len_mean = 80.37
# SAC iter 096 | reward_mean = -35.623 | len_mean = 75.39
# SAC iter 097 | reward_mean = -30.166 | len_mean = 70.18
# SAC iter 098 | reward_mean = -26.699 | len_mean = 64.86
# SAC iter 099 | reward_mean = -23.175 | len_mean = 60.18
# SAC iter 100 | reward_mean = -17.075 | len_mean = 51.12
# SAC iter 101 | reward_mean = -16.799 | len_mean = 50.76
# SAC iter 102 | reward_mean = -13.126 | len_mean = 45.62
# SAC iter 103 | reward_mean = -13.126 | len_mean = 45.62
# SAC iter 104 | reward_mean = -10.935 | len_mean = 41.22
# SAC iter 105 | reward_mean = -7.720 | len_mean = 35.79
# SAC iter 106 | reward_mean = -7.521 | len_mean = 35.36
# SAC iter 107 | reward_mean = -5.757 | len_mean = 32.21
# SAC iter 108 | reward_mean = -5.631 | len_mean = 32.11
# SAC iter 109 | reward_mean = -5.862 | len_mean = 32.86
# SAC iter 110 | reward_mean = -5.784 | len_mean = 32.62
# SAC iter 111 | reward_mean = -5.636 | len_mean = 32.52
# SAC iter 112 | reward_mean = -5.625 | len_mean = 33.05
# SAC iter 113 | reward_mean = -4.925 | len_mean = 31.73
# SAC iter 114 | reward_mean = -5.177 | len_mean = 32.27
# SAC iter 115 | reward_mean = -4.685 | len_mean = 31.86
# SAC iter 116 | reward_mean = -4.411 | len_mean = 31.29
# SAC iter 117 | reward_mean = -3.598 | len_mean = 29.35
# SAC iter 118 | reward_mean = -3.361 | len_mean = 29.07
# SAC iter 119 | reward_mean = -2.626 | len_mean = 26.89
# SAC iter 120 | reward_mean = -1.800 | len_mean = 24.87
# SAC iter 121 | reward_mean = -1.668 | len_mean = 24.89
# SAC iter 122 | reward_mean = -1.222 | len_mean = 24.23
# SAC iter 123 | reward_mean = -1.170 | len_mean = 23.87
# SAC iter 124 | reward_mean = -1.318 | len_mean = 24.27
# SAC iter 125 | reward_mean = -0.911 | len_mean = 23.33
# SAC iter 126 | reward_mean = -0.332 | len_mean = 21.82
# SAC iter 127 | reward_mean = 0.067 | len_mean = 21.26
# SAC iter 128 | reward_mean = -0.178 | len_mean = 21.02
# SAC iter 129 | reward_mean = 0.035 | len_mean = 20.09
# SAC iter 130 | reward_mean = 0.955 | len_mean = 18.31
# SAC iter 131 | reward_mean = 0.920 | len_mean = 18.07
# SAC iter 132 | reward_mean = 1.341 | len_mean = 16.61
# SAC iter 133 | reward_mean = 1.384 | len_mean = 16.28
# SAC iter 134 | reward_mean = 1.661 | len_mean = 15.63
# SAC iter 135 | reward_mean = 1.735 | len_mean = 15.38
# SAC iter 136 | reward_mean = 1.516 | len_mean = 16.18
# SAC iter 137 | reward_mean = 1.572 | len_mean = 15.35
# SAC iter 138 | reward_mean = 1.145 | len_mean = 15.99
# SAC iter 139 | reward_mean = 1.381 | len_mean = 15.22
# SAC iter 140 | reward_mean = 1.556 | len_mean = 14.93
# SAC iter 141 | reward_mean = 1.319 | len_mean = 15.52
# SAC iter 142 | reward_mean = 1.100 | len_mean = 16.29
# SAC iter 143 | reward_mean = 1.298 | len_mean = 15.85
# SAC iter 144 | reward_mean = 1.472 | len_mean = 16.11
# SAC iter 145 | reward_mean = 1.261 | len_mean = 16.13
# SAC iter 146 | reward_mean = 1.098 | len_mean = 16.16
# SAC iter 147 | reward_mean = 1.340 | len_mean = 15.91
# SAC iter 148 | reward_mean = 1.362 | len_mean = 15.54
# SAC iter 149 | reward_mean = 1.338 | len_mean = 15.90
# SAC iter 150 | reward_mean = 1.139 | len_mean = 16.05
# SAC iter 151 | reward_mean = 0.953 | len_mean = 16.33
# SAC iter 152 | reward_mean = 1.212 | len_mean = 15.38
# SAC iter 153 | reward_mean = 1.651 | len_mean = 14.67
# SAC iter 154 | reward_mean = 1.952 | len_mean = 14.50
# SAC iter 155 | reward_mean = 2.255 | len_mean = 13.46
# SAC iter 156 | reward_mean = 2.336 | len_mean = 13.16
# SAC iter 157 | reward_mean = 2.253 | len_mean = 13.09
# SAC iter 158 | reward_mean = 2.078 | len_mean = 13.56
# SAC iter 159 | reward_mean = 2.062 | len_mean = 13.36
# SAC iter 160 | reward_mean = 1.842 | len_mean = 13.50
# SAC iter 161 | reward_mean = 1.749 | len_mean = 13.73
# SAC iter 162 | reward_mean = 1.774 | len_mean = 13.36
# SAC iter 163 | reward_mean = 1.876 | len_mean = 13.40
# SAC iter 164 | reward_mean = 1.940 | len_mean = 13.24
# SAC iter 165 | reward_mean = 2.113 | len_mean = 13.08
# SAC iter 166 | reward_mean = 1.761 | len_mean = 13.53
# SAC iter 167 | reward_mean = 1.505 | len_mean = 13.74
# SAC iter 168 | reward_mean = 1.533 | len_mean = 13.52
# SAC iter 169 | reward_mean = 1.285 | len_mean = 13.76
# SAC iter 170 | reward_mean = 1.138 | len_mean = 14.18
# SAC iter 171 | reward_mean = 1.324 | len_mean = 13.58
# SAC iter 172 | reward_mean = 1.418 | len_mean = 13.69
# SAC iter 173 | reward_mean = 1.425 | len_mean = 13.82
# SAC iter 174 | reward_mean = 1.741 | len_mean = 13.62
# SAC iter 175 | reward_mean = 1.897 | len_mean = 13.47
# SAC iter 176 | reward_mean = 1.947 | len_mean = 13.29
# SAC iter 177 | reward_mean = 1.822 | len_mean = 13.34
# SAC iter 178 | reward_mean = 1.823 | len_mean = 13.39
# SAC iter 179 | reward_mean = 1.917 | len_mean = 13.27
# SAC iter 180 | reward_mean = 2.152 | len_mean = 13.10
# SAC iter 181 | reward_mean = 1.815 | len_mean = 13.35
# SAC iter 182 | reward_mean = 2.231 | len_mean = 12.86
# SAC iter 183 | reward_mean = 2.280 | len_mean = 12.70
# SAC iter 184 | reward_mean = 2.432 | len_mean = 12.65
# SAC iter 185 | reward_mean = 2.566 | len_mean = 12.21
# SAC iter 186 | reward_mean = 2.373 | len_mean = 12.14
# SAC iter 187 | reward_mean = 2.119 | len_mean = 12.17
# SAC iter 188 | reward_mean = 2.002 | len_mean = 12.28
# SAC iter 189 | reward_mean = 1.956 | len_mean = 12.24
# SAC iter 190 | reward_mean = 1.956 | len_mean = 12.11
# SAC iter 191 | reward_mean = 2.113 | len_mean = 11.98
# SAC iter 192 | reward_mean = 2.182 | len_mean = 11.67
# SAC iter 193 | reward_mean = 2.376 | len_mean = 11.50
# SAC iter 194 | reward_mean = 2.208 | len_mean = 11.77
# SAC iter 195 | reward_mean = 2.456 | len_mean = 11.52
# SAC iter 196 | reward_mean = 2.524 | len_mean = 11.41
# SAC iter 197 | reward_mean = 2.503 | len_mean = 11.35
# SAC iter 198 | reward_mean = 2.447 | len_mean = 11.47
# SAC iter 199 | reward_mean = 2.799 | len_mean = 11.15
# SAC iter 200 | reward_mean = 2.838 | len_mean = 11.27

# %%
# fresh env for evaluation
record_env = FrogFly3DEnv(env_config)

sac_policy = trained_policy_factory(sac_algo)

frog_sac, fly_sac = rollout_trajectory(
    record_env,
    policy_fn=sac_policy,
    max_steps=200,
)

make_3d_gif(
    frog_sac,
    fly_sac,
    out_path="frog_fly_sac.gif",
    title="SAC Frog vs Fly (Continuous)",
)

print("Saved GIF: frog_fly_sac.gif")
# Out:
# Saved GIF: frog_fly_sac.gif

# %%
from ray.rllib.algorithms.impala import IMPALAConfig

ray.shutdown()
ray.init(ignore_reinit_error=True)

impala_config = (
    IMPALAConfig()
    .environment(env=FrogFly3DEnv, env_config=env_config)
    .framework("torch")
    .resources(num_gpus=0)
    .env_runners(
        num_env_runners=1,
        # you can tune this; smaller = more frequent updates, larger = more throughput
        rollout_fragment_length=100,
    )
    .training(
        gamma=0.99,
        lr=3e-4,
        train_batch_size=2048,   # or omit if this complains; defaults will kick in
        model={
            "fcnet_hiddens": [256, 256],
            "fcnet_activation": "tanh",
        },
    )
)

impala_algo = impala_config.build()
print("IMPALA algo built OK")
# Out:
# 2025-12-02 23:25:36,435	INFO worker.py:2023 -- Started a local Ray instance.
# 2025-12-02 23:25:37,112	WARNING algorithm_config.py:5058 -- You are running IMPALA on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/anaconda3/envs/rl-project/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (SingleAgentEnvRunner pid=12138) DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# (_WrappedExecutable pid=12141) Setting up process group for: env:// [rank=0, world_size=1]
# 2025-12-02 23:25:42,102	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# IMPALA algo built OK

# %%
num_impala_iters = 200

impala_mean_rewards = []
impala_mean_lengths = []

for i in range(num_impala_iters):
    result = impala_algo.train()

    if "env_runners" in result:
        env_metrics = result["env_runners"]
        mean_r = env_metrics.get("episode_return_mean", float("nan"))
        mean_l = env_metrics.get("episode_len_mean", float("nan"))
    else:
        mean_r = result.get("episode_reward_mean", float("nan"))
        mean_l = result.get("episode_len_mean", float("nan"))

    impala_mean_rewards.append(mean_r)
    impala_mean_lengths.append(mean_l)

    print(
        f"IMPALA iter {i+1:03d} | "
        f"reward_mean = {mean_r:.3f} | "
        f"len_mean = {mean_l:.2f}"
    )
# Out:
# IMPALA iter 001 | reward_mean = -273.999 | len_mean = 189.23
# IMPALA iter 002 | reward_mean = -283.671 | len_mean = 192.99
# (pid=gcs_server) [2025-12-02 23:26:05,748 E 12126 65243476] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-02 23:26:06,376 E 12131 65243576] (raylet) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (SingleAgentEnvRunner pid=12138) [2025-12-02 23:26:06,952 E 12138 65243824] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-12-02 23:26:07,128 E 11711 65243625] core_worker_process.cc:837: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# IMPALA iter 003 | reward_mean = -287.475 | len_mean = 194.00
# IMPALA iter 004 | reward_mean = -277.502 | len_mean = 190.41
# IMPALA iter 005 | reward_mean = -293.977 | len_mean = 194.03
# IMPALA iter 006 | reward_mean = -288.660 | len_mean = 192.89
# IMPALA iter 007 | reward_mean = -311.685 | len_mean = 195.38
# IMPALA iter 008 | reward_mean = -316.579 | len_mean = 191.75
# IMPALA iter 009 | reward_mean = -318.160 | len_mean = 194.92
# IMPALA iter 010 | reward_mean = -304.728 | len_mean = 192.94
# IMPALA iter 011 | reward_mean = -309.811 | len_mean = 195.30
# IMPALA iter 012 | reward_mean = -301.100 | len_mean = 194.19
# IMPALA iter 013 | reward_mean = -321.853 | len_mean = 195.62
# IMPALA iter 014 | reward_mean = -299.508 | len_mean = 184.31
# IMPALA iter 015 | reward_mean = -327.025 | len_mean = 197.22
# IMPALA iter 016 | reward_mean = -307.410 | len_mean = 193.99
# IMPALA iter 017 | reward_mean = -314.591 | len_mean = 195.38
# IMPALA iter 018 | reward_mean = -316.150 | len_mean = 195.36
# IMPALA iter 019 | reward_mean = -305.334 | len_mean = 191.47
# IMPALA iter 020 | reward_mean = -289.995 | len_mean = 190.44
# IMPALA iter 021 | reward_mean = -299.845 | len_mean = 186.01
# IMPALA iter 022 | reward_mean = -313.133 | len_mean = 192.27
# IMPALA iter 023 | reward_mean = -299.918 | len_mean = 189.17
# IMPALA iter 024 | reward_mean = -329.233 | len_mean = 192.95
# IMPALA iter 025 | reward_mean = -289.804 | len_mean = 187.28
# IMPALA iter 026 | reward_mean = -306.922 | len_mean = 194.72
# IMPALA iter 027 | reward_mean = -308.644 | len_mean = 194.54
# IMPALA iter 028 | reward_mean = -308.344 | len_mean = 191.36
# IMPALA iter 029 | reward_mean = -304.790 | len_mean = 191.17
# IMPALA iter 030 | reward_mean = -308.646 | len_mean = 197.01
# IMPALA iter 031 | reward_mean = -293.181 | len_mean = 196.95
# IMPALA iter 032 | reward_mean = -318.634 | len_mean = 197.89
# IMPALA iter 033 | reward_mean = -310.206 | len_mean = 197.23
# IMPALA iter 034 | reward_mean = -298.219 | len_mean = 191.97
# IMPALA iter 035 | reward_mean = -313.254 | len_mean = 193.94
# IMPALA iter 036 | reward_mean = -308.144 | len_mean = 195.31
# IMPALA iter 037 | reward_mean = -304.402 | len_mean = 195.00
# IMPALA iter 038 | reward_mean = -299.323 | len_mean = 194.58
# IMPALA iter 039 | reward_mean = -279.843 | len_mean = 186.90
# IMPALA iter 040 | reward_mean = -305.461 | len_mean = 194.05
# IMPALA iter 041 | reward_mean = -301.098 | len_mean = 188.28
# IMPALA iter 042 | reward_mean = -305.153 | len_mean = 194.45
# IMPALA iter 043 | reward_mean = -294.435 | len_mean = 189.62
# IMPALA iter 044 | reward_mean = -284.482 | len_mean = 189.22
# IMPALA iter 045 | reward_mean = -314.875 | len_mean = 196.38
# IMPALA iter 046 | reward_mean = -307.978 | len_mean = 193.77
# IMPALA iter 047 | reward_mean = -308.297 | len_mean = 193.36
# IMPALA iter 048 | reward_mean = -293.217 | len_mean = 193.67
# IMPALA iter 049 | reward_mean = -307.940 | len_mean = 195.45
# IMPALA iter 050 | reward_mean = -306.752 | len_mean = 189.25
# IMPALA iter 051 | reward_mean = -303.796 | len_mean = 193.16
# IMPALA iter 052 | reward_mean = -307.986 | len_mean = 194.61
# IMPALA iter 053 | reward_mean = -292.238 | len_mean = 193.21
# IMPALA iter 054 | reward_mean = -294.126 | len_mean = 188.70
# IMPALA iter 055 | reward_mean = -303.444 | len_mean = 192.41
# IMPALA iter 056 | reward_mean = -300.742 | len_mean = 191.48
# IMPALA iter 057 | reward_mean = -290.052 | len_mean = 192.26
# IMPALA iter 058 | reward_mean = -300.787 | len_mean = 194.41
# IMPALA iter 059 | reward_mean = -309.083 | len_mean = 196.56
# IMPALA iter 060 | reward_mean = -318.733 | len_mean = 193.29
# IMPALA iter 061 | reward_mean = -301.933 | len_mean = 194.01
# IMPALA iter 062 | reward_mean = -310.882 | len_mean = 198.57
# IMPALA iter 063 | reward_mean = -316.133 | len_mean = 196.94
# IMPALA iter 064 | reward_mean = -297.721 | len_mean = 192.09
# IMPALA iter 065 | reward_mean = -308.632 | len_mean = 195.45
# IMPALA iter 066 | reward_mean = -302.127 | len_mean = 194.28
# IMPALA iter 067 | reward_mean = -291.112 | len_mean = 193.81
# IMPALA iter 068 | reward_mean = -303.958 | len_mean = 193.93
# IMPALA iter 069 | reward_mean = -309.681 | len_mean = 193.96
# IMPALA iter 070 | reward_mean = -304.432 | len_mean = 192.45
# IMPALA iter 071 | reward_mean = -296.999 | len_mean = 191.00
# IMPALA iter 072 | reward_mean = -308.411 | len_mean = 192.72
# IMPALA iter 073 | reward_mean = -296.596 | len_mean = 183.76
# IMPALA iter 074 | reward_mean = -298.250 | len_mean = 196.13
# IMPALA iter 075 | reward_mean = -309.408 | len_mean = 198.33
# IMPALA iter 076 | reward_mean = -305.036 | len_mean = 195.67
# IMPALA iter 077 | reward_mean = -308.707 | len_mean = 192.75
# IMPALA iter 078 | reward_mean = -283.945 | len_mean = 186.25
# IMPALA iter 079 | reward_mean = -297.551 | len_mean = 194.08
# IMPALA iter 080 | reward_mean = -314.820 | len_mean = 194.99
# IMPALA iter 081 | reward_mean = -301.711 | len_mean = 195.03
# IMPALA iter 082 | reward_mean = -286.392 | len_mean = 195.42
# IMPALA iter 083 | reward_mean = -302.044 | len_mean = 192.49
# IMPALA iter 084 | reward_mean = -312.794 | len_mean = 195.31
# IMPALA iter 085 | reward_mean = -309.509 | len_mean = 199.22
# IMPALA iter 086 | reward_mean = -307.441 | len_mean = 193.36
# IMPALA iter 087 | reward_mean = -319.173 | len_mean = 198.70
# IMPALA iter 088 | reward_mean = -307.987 | len_mean = 198.47
# IMPALA iter 089 | reward_mean = -314.319 | len_mean = 196.03
# IMPALA iter 090 | reward_mean = -300.271 | len_mean = 193.68
# IMPALA iter 091 | reward_mean = -326.003 | len_mean = 195.19
# IMPALA iter 092 | reward_mean = -317.820 | len_mean = 195.67
# IMPALA iter 093 | reward_mean = -309.769 | len_mean = 196.31
# IMPALA iter 094 | reward_mean = -325.901 | len_mean = 195.21
# IMPALA iter 095 | reward_mean = -301.325 | len_mean = 191.88
# IMPALA iter 096 | reward_mean = -301.332 | len_mean = 190.88
# IMPALA iter 097 | reward_mean = -304.479 | len_mean = 191.37
# IMPALA iter 098 | reward_mean = -310.010 | len_mean = 196.39
# IMPALA iter 099 | reward_mean = -293.282 | len_mean = 187.81
# IMPALA iter 100 | reward_mean = -296.726 | len_mean = 193.20
# IMPALA iter 101 | reward_mean = -312.973 | len_mean = 196.44
# IMPALA iter 102 | reward_mean = -302.286 | len_mean = 193.54
# IMPALA iter 103 | reward_mean = -308.042 | len_mean = 194.56
# IMPALA iter 104 | reward_mean = -309.426 | len_mean = 197.49
# IMPALA iter 105 | reward_mean = -297.568 | len_mean = 193.34
# IMPALA iter 106 | reward_mean = -308.587 | len_mean = 192.94
# IMPALA iter 107 | reward_mean = -296.759 | len_mean = 194.78
# IMPALA iter 108 | reward_mean = -305.882 | len_mean = 199.58
# IMPALA iter 109 | reward_mean = -288.185 | len_mean = 191.69
# IMPALA iter 110 | reward_mean = -304.369 | len_mean = 193.08
# IMPALA iter 111 | reward_mean = -297.403 | len_mean = 189.78
# IMPALA iter 112 | reward_mean = -315.945 | len_mean = 194.31
# IMPALA iter 113 | reward_mean = -307.438 | len_mean = 193.68
# IMPALA iter 114 | reward_mean = -302.964 | len_mean = 195.72
# IMPALA iter 115 | reward_mean = -312.024 | len_mean = 195.05
# IMPALA iter 116 | reward_mean = -308.591 | len_mean = 192.67
# IMPALA iter 117 | reward_mean = -299.903 | len_mean = 193.94
# IMPALA iter 118 | reward_mean = -306.049 | len_mean = 194.82
# IMPALA iter 119 | reward_mean = -295.424 | len_mean = 191.30
# IMPALA iter 120 | reward_mean = -293.457 | len_mean = 196.00
# IMPALA iter 121 | reward_mean = -292.187 | len_mean = 189.76
# IMPALA iter 122 | reward_mean = -292.409 | len_mean = 194.58
# IMPALA iter 123 | reward_mean = -286.751 | len_mean = 188.69
# IMPALA iter 124 | reward_mean = -294.825 | len_mean = 189.36
# IMPALA iter 125 | reward_mean = -331.926 | len_mean = 197.11
# IMPALA iter 126 | reward_mean = -302.242 | len_mean = 189.43
# IMPALA iter 127 | reward_mean = -314.700 | len_mean = 196.83
# IMPALA iter 128 | reward_mean = -296.072 | len_mean = 190.20
# IMPALA iter 129 | reward_mean = -320.578 | len_mean = 196.99
# IMPALA iter 130 | reward_mean = -301.792 | len_mean = 189.80
# IMPALA iter 131 | reward_mean = -310.615 | len_mean = 196.71
# IMPALA iter 132 | reward_mean = -286.660 | len_mean = 186.87
# IMPALA iter 133 | reward_mean = -293.098 | len_mean = 192.22
# IMPALA iter 134 | reward_mean = -304.754 | len_mean = 192.93
# IMPALA iter 135 | reward_mean = -311.734 | len_mean = 196.11
# IMPALA iter 136 | reward_mean = -307.554 | len_mean = 194.81
# IMPALA iter 137 | reward_mean = -286.648 | len_mean = 194.20
# IMPALA iter 138 | reward_mean = -304.558 | len_mean = 197.16
# IMPALA iter 139 | reward_mean = -303.893 | len_mean = 194.08
# IMPALA iter 140 | reward_mean = -313.378 | len_mean = 193.75
# IMPALA iter 141 | reward_mean = -303.783 | len_mean = 186.25
# IMPALA iter 142 | reward_mean = -321.066 | len_mean = 198.05
# IMPALA iter 143 | reward_mean = -311.421 | len_mean = 195.76
# IMPALA iter 144 | reward_mean = -285.211 | len_mean = 193.54
# IMPALA iter 145 | reward_mean = -304.135 | len_mean = 191.76
# IMPALA iter 146 | reward_mean = -315.013 | len_mean = 194.63
# IMPALA iter 147 | reward_mean = -313.766 | len_mean = 194.72
# IMPALA iter 148 | reward_mean = -309.949 | len_mean = 193.40
# IMPALA iter 149 | reward_mean = -302.894 | len_mean = 196.47
# IMPALA iter 150 | reward_mean = -277.049 | len_mean = 192.69
# IMPALA iter 151 | reward_mean = -313.084 | len_mean = 196.20
# IMPALA iter 152 | reward_mean = -294.370 | len_mean = 197.25
# IMPALA iter 153 | reward_mean = -312.069 | len_mean = 197.72
# IMPALA iter 154 | reward_mean = -284.675 | len_mean = 188.70
# IMPALA iter 155 | reward_mean = -295.624 | len_mean = 196.50
# IMPALA iter 156 | reward_mean = -323.313 | len_mean = 198.02
# IMPALA iter 157 | reward_mean = -316.599 | len_mean = 198.02
# IMPALA iter 158 | reward_mean = -305.366 | len_mean = 195.68
# IMPALA iter 159 | reward_mean = -308.870 | len_mean = 194.65
# IMPALA iter 160 | reward_mean = -315.741 | len_mean = 193.66
# IMPALA iter 161 | reward_mean = -308.111 | len_mean = 193.22
# IMPALA iter 162 | reward_mean = -311.714 | len_mean = 191.82
# IMPALA iter 163 | reward_mean = -305.541 | len_mean = 192.05
# IMPALA iter 164 | reward_mean = -302.911 | len_mean = 191.97
# IMPALA iter 165 | reward_mean = -280.519 | len_mean = 190.50
# IMPALA iter 166 | reward_mean = -284.974 | len_mean = 191.25
# IMPALA iter 167 | reward_mean = -296.400 | len_mean = 195.32
# IMPALA iter 168 | reward_mean = -306.546 | len_mean = 197.05
# IMPALA iter 169 | reward_mean = -293.320 | len_mean = 190.35
# IMPALA iter 170 | reward_mean = -295.829 | len_mean = 194.63
# IMPALA iter 171 | reward_mean = -315.582 | len_mean = 198.53
# IMPALA iter 172 | reward_mean = -317.458 | len_mean = 200.00
# IMPALA iter 173 | reward_mean = -321.662 | len_mean = 196.00
# IMPALA iter 174 | reward_mean = -300.691 | len_mean = 192.48
# IMPALA iter 175 | reward_mean = -325.610 | len_mean = 198.54
# IMPALA iter 176 | reward_mean = -309.911 | len_mean = 193.87
# IMPALA iter 177 | reward_mean = -304.378 | len_mean = 196.12
# IMPALA iter 178 | reward_mean = -308.068 | len_mean = 195.38
# IMPALA iter 179 | reward_mean = -313.662 | len_mean = 196.06
# IMPALA iter 180 | reward_mean = -292.971 | len_mean = 197.50
# IMPALA iter 181 | reward_mean = -316.896 | len_mean = 196.28
# IMPALA iter 182 | reward_mean = -307.425 | len_mean = 189.33
# IMPALA iter 183 | reward_mean = -301.951 | len_mean = 190.96
# IMPALA iter 184 | reward_mean = -325.170 | len_mean = 193.55
# IMPALA iter 185 | reward_mean = -316.147 | len_mean = 196.62
# IMPALA iter 186 | reward_mean = -299.721 | len_mean = 198.27
# IMPALA iter 187 | reward_mean = -303.344 | len_mean = 191.81
# IMPALA iter 188 | reward_mean = -303.491 | len_mean = 194.31
# IMPALA iter 189 | reward_mean = -300.863 | len_mean = 188.14
# IMPALA iter 190 | reward_mean = -304.235 | len_mean = 192.19
# IMPALA iter 191 | reward_mean = -302.029 | len_mean = 194.97
# IMPALA iter 192 | reward_mean = -310.888 | len_mean = 197.59
# IMPALA iter 193 | reward_mean = -304.771 | len_mean = 190.24
# IMPALA iter 194 | reward_mean = -309.648 | len_mean = 196.78
# IMPALA iter 195 | reward_mean = -315.100 | len_mean = 195.54
# IMPALA iter 196 | reward_mean = -311.861 | len_mean = 197.45
# IMPALA iter 197 | reward_mean = -303.695 | len_mean = 189.23
# IMPALA iter 198 | reward_mean = -334.544 | len_mean = 198.52
# IMPALA iter 199 | reward_mean = -312.344 | len_mean = 196.53
# IMPALA iter 200 | reward_mean = -304.744 | len_mean = 197.07

# %%
# fresh env for evaluation
record_env = FrogFly3DEnv(env_config)

impala_policy = trained_policy_factory(impala_algo)

frog_impala, fly_impala = rollout_trajectory(
    record_env,
    policy_fn=impala_policy,
    max_steps=200,
)

make_3d_gif(
    frog_impala,
    fly_impala,
    out_path="frog_fly_impala.gif",
    title="IMPALA Frog vs Fly (Continuous)",
)

print("Saved GIF: frog_fly_impala.gif")
# Out:
# Saved GIF: frog_fly_impala.gif

# %%
import matplotlib.pyplot as plt
import numpy as np

iters_ppo = np.arange(1, len(mean_rewards) + 1)
iters_sac = np.arange(1, len(sac_mean_rewards) + 1)
iters_imp = np.arange(1, len(impala_mean_rewards) + 1)

plt.figure(figsize=(10, 5))
plt.plot(iters_ppo, mean_rewards, label="PPO")
plt.plot(iters_sac, sac_mean_rewards, label="SAC")
plt.plot(iters_imp, impala_mean_rewards, label="IMPALA")
plt.xlabel("Training iteration")
plt.ylabel("Mean episode return")
plt.title("Frog–Fly: PPO vs SAC vs IMPALA")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

iters_ppo = np.arange(1, len(mean_lengths) + 1)
iters_sac = np.arange(1, len(sac_mean_lengths) + 1)
iters_imp = np.arange(1, len(impala_mean_lengths) + 1)

plt.figure(figsize=(10, 5))
plt.plot(iters_ppo, mean_lengths, label="PPO")
plt.plot(iters_sac, sac_mean_lengths, label="SAC")
plt.plot(iters_imp, impala_mean_lengths, label="IMPALA")
plt.xlabel("Training iteration")
plt.ylabel("Episode Length (steps)")
plt.title("Frog–Fly: PPO vs SAC vs IMPALA")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reinforcement Learning Algorithms (PPO, SAC, IMPALA)
#
# ---
#
# ### Proximal Policy Optimization (PPO)
#
# Probability ratio:
#
# $$
# r_t(\theta) =
# \dfrac{\pi_\theta(a_t|s_t)}
# {\pi_{\theta_{\text{old}}}(a_t|s_t)}
# $$
#
# Advantage estimate:
#
# $$
# A_t = \sum_{k=0}^{T-t} \gamma^k r_{t+k} - V_\phi(s_t)
# $$
#
# Clipped PPO objective:
#
# $$
# J(\theta) =
# \mathbb{E}_t\Big[
# \min(
# r_t(\theta)A_t,\,
# \text{clip}(r_t(\theta),1-\epsilon,1+\epsilon)A_t
# )\Big]
# $$
#
# Value regression loss:
#
# $$
# L_V(\phi)=\mathbb{E}_t[(V_\phi(s_t)-R_t)^2]
# $$
#
# ---
#
# ### Soft Actor–Critic (SAC)
#
# Maximum entropy policy objective:
#
# $$
# J(\theta) =
# \mathbb{E}_{(s_t,a_t)\sim\mathcal{D}}
# \Big[
# Q_\phi(s_t,a_t) - \alpha \log \pi_\theta(a_t|s_t)
# \Big]
# $$
#
# Soft Bellman backup:
#
# $$
# Q_\phi(s_t,a_t)=
# r_t + \gamma\,\mathbb{E}_{a_{t+1}\sim\pi}
# \Big[
# Q_\phi(s_{t+1},a_{t+1})
# - \alpha \log \pi(a_{t+1}|s_{t+1})
# \Big]
# $$
#
# ---
#
# ### IMPALA (V-Trace Off-Policy Correction)
#
# V-trace return:
#
# $$
# v_t = V(s_t) +
# \sum_{k=t}^{t+n-1}
# \gamma^{k-t}
# \Bigg(
# \prod_{i=t}^{k-1} c_i
# \Bigg)
# \delta_k
# $$
#
# TD error with clipped importance ratio:
#
# $$
# \delta_t =
# \rho_t \Big(
# r_t + \gamma V(s_{t+1}) - V(s_t)
# \Big)
# $$
#
# Importance sampling ratios:
#
# $$
# \rho_t = \frac{\pi(a_t|s_t)}{\mu(a_t|s_t)}, \qquad
# c_t = \min(1,\rho_t)
# $$
